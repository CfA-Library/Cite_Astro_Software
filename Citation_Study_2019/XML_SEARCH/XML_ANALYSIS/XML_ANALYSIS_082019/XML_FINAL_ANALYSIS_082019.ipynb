# %% [markdown]
# # XML Final Analysis
# ### Daina Bouquin, Daniel Chivvis
#
# Scripts below were used to generate all .csv files in the XML_RESULTS_082019/ folder

# %%
import pandas as pd
import numpy as np
import sys
import csv

# %%
XML_results = pd.read_csv("XML_CLEAN_INPUT_082019.csv")

# %%
list(XML_results.columns.values)
# Out:
# ['Alias',
#  'Software_Package',
#  'Identifier',
#  'Pub_Year',
#  'DOI',
#  'Journal_Title',
#  'Article_ID',
#  'File_Name',
#  'Parent1_Tag',
#  'Parent2_Tag',
#  'Parent3_Tag',
#  'Parent4_Tag',
#  'Parent1_Content',
#  'Parent2_Content',
#  'Parent3_Content',
#  'Author(s)',
#  'Publisher',
#  'Title']

# %%
XML_results.head(5)
# Out:
#                          Alias Software_Package  Identifier  Pub_Year  \
# 0                   astroblend       AstroBlend           0      2016
# 1               astroblend.com       AstroBlend           0      2016
# 2  10.1051/0004-6361/201322068          Astropy           1      2014
# 3  10.1051/0004-6361/201322068          Astropy           1      2014
# 4  10.1051/0004-6361/201322068          Astropy           1      2014
#
#                            DOI              Journal_Title  \
# 0  10.3847/0004-637X/818/2/115  The Astrophysical Journal
# 1  10.3847/0004-637X/818/2/115  The Astrophysical Journal
# 2   10.1088/0004-6256/148/1/13   The Astronomical Journal
# 3   10.1088/0004-6256/148/1/14   The Astronomical Journal
# 4   10.1088/0004-6256/148/3/53   The Astronomical Journal
#
#                                           Article_ID          File_Name  \
# 0  apj521773, 10.3847/0004-637X/818/2/115, 521773...  apj_818_2_115.xml
# 1  apj521773, 10.3847/0004-637X/818/2/115, 521773...  apj_818_2_115.xml
# 2  aj493368, ANJOAA, 10.1088/0004-6256/148/1/13, ...    aj_148_1_13.xml
# 3  aj495229, ANJOAA, 10.1088/0004-6256/148/1/14, ...    aj_148_1_14.xml
# 4  aj499538, ANJOAA, 10.1088/0004-6256/148/3/53, ...    aj_148_3_53.xml
#
#   Parent1_Tag   Parent2_Tag Parent3_Tag Parent4_Tag  \
# 0          sc             p         sec         sec
# 1    ext-link             p          fn           p
# 2    ext-link  nlm-citation         ref    ref-list
# 3    ext-link  nlm-citation         ref    ref-list
# 4    ext-link  nlm-citation         ref    ref-list
#
#                    Parent1_Content  \
# 0                   ['astroblend']
# 1    ['http://www.astroblend.com']
# 2  ['10.1051/0004-6361/201322068']
# 3  ['10.1051/0004-6361/201322068']
# 4  ['10.1051/0004-6361/201322068']
#
#                                      Parent2_Content  \
# 0  ['We note that our example scripts only explor...
# 1  ['\n<ext-link ext-link-type="uri" xlink:href="...
# 2  ['\n<person-group person-group-type="author">\...
# 3  ['\n<person-group person-group-type="author">\...
# 4  ['\n<person-group person-group-type="author">\...
#
#                                      Parent3_Content  \
# 0  ['\n<label>3.5.</label>\n<title>From <sans-ser...
# 1  ['\n<label><sup>26</sup></label>\n<p>\n<ext-li...
# 2  ['\n<nlm-citation citation-type="journal">\n<p...
# 3  ['\n<nlm-citation citation-type="journal">\n<p...
# 4  ['\n<nlm-citation citation-type="journal">\n<p...
#
#                                            Author(s)  \
# 0  Vogt Frédéric P. A.  Owen Chris I.  Verdes-Mon...
# 1  Vogt Frédéric P. A.  Owen Chris I.  Verdes-Mon...
# 2  Rodney Steven A.Riess Adam G.Strolger Louis-Gr...
# 3  Bañados E.Venemans B. P.Morganson E.Decarli R....
# 4  Gullikson KevinDodson-Robinson SarahKraus Adam...
#
#                            Publisher  \
# 0  The American Astronomical Society
# 1  The American Astronomical Society
# 2  The American Astronomical Society
# 3  The American Astronomical Society
# 4  The American Astronomical Society
#
#                                                Title
# 0  ADVANCED DATA VISUALIZATION IN ASTROPHYSICS: T...
# 1  ADVANCED DATA VISUALIZATION IN ASTROPHYSICS: T...
# 2  TYPE Ia SUPERNOVA RATE MEASUREMENTS TO REDSHIF...
# 3  DISCOVERY OF EIGHT z ∼ 6 QUASARS FROM Pan-STARRS1
# 4  CORRECTING FOR TELLURIC ABSORPTION: METHODS, C...

# %%
# Convert tag, content, identifier, pub_year cols to strings

XML_results['Parent1_Tag'] = XML_results['Parent1_Tag'].astype('|S')
XML_results['Parent2_Tag'] = XML_results['Parent2_Tag'].astype('|S')
XML_results['Parent3_Tag'] = XML_results['Parent3_Tag'].astype('|S')
XML_results['Parent4_Tag'] = XML_results['Parent4_Tag'].astype('|S')

XML_results['Parent1_Content'] = XML_results['Parent1_Content'].astype('|S')
XML_results['Parent2_Content'] = XML_results['Parent2_Content'].astype('|S')
XML_results['Parent3_Content'] = XML_results['Parent3_Content'].astype('|S')

XML_results['Identifier'] = XML_results['Identifier'].astype('|S')
XML_results['Pub_Year'] = XML_results['Pub_Year'].astype('|S')
XML_results['Alias'] = XML_results['Alias'].astype('|S')

# %%
# Create column for reference section

# If the tag lable or tag content contain any of the following reference elements it will be marked "yes":
# element-citation 
# mixed-citation
# nlm-citation
# ref
# citation-alternatives
# ref-list 
# xref
# source
# bibr
# collab
# contrib-group
# person-group
# pub-id

references = ['Parent1_Tag','Parent2_Tag','Parent3_Tag','Parent4_Tag','Parent1_Content','Parent2_Content']
XML_results["ref"] = np.where((XML_results[references] == "element-citation").any(axis=1) | (XML_results[references]== "mixed-citation").any(axis=1) | (XML_results[references]== "nlm-citation").any(axis=1) | (XML_results[references]== "ref").any(axis=1) | (XML_results[references]== "citation-alternatives").any(axis=1) | (XML_results[references]== "ref-list").any(axis=1) | (XML_results[references]== "xref").any(axis=1) | (XML_results[references]== "source").any(axis=1) | (XML_results[references]== "collab").any(axis=1) | (XML_results[references]== "contrib-group").any(axis=1) | (XML_results[references]== "person-group").any(axis=1) | (XML_results[references]== "pub-id").any(axis=1) | (XML_results[references]== "bibr").any(axis=1), "yes", "no")

# %%
# Create column for acknowledgements
# If the tag lable or tag content contains "ack" it will be marked "yes"

acknowledgements = ['Parent1_Tag','Parent2_Tag','Parent3_Tag','Parent4_Tag','Parent1_Content','Parent2_Content']
XML_results["ack"] = np.where((XML_results[acknowledgements] == "ack").any(axis=1), "yes", "no")

# %%
# Create column for footnotes
# If the tag lable or tag content contains "fn" or "fn-group" it will be marked "yes"

footnotes = ['Parent1_Tag','Parent2_Tag','Parent3_Tag','Parent4_Tag','Parent1_Content','Parent2_Content']
XML_results["fn"] = np.where((XML_results[footnotes] == "fn").any(axis=1) | (XML_results[footnotes]== "fn-group").any(axis=1), "yes", "no")

# %%
# Create column for attempt at recognizable credit (ref + ack + fn + ext-link + back)

# element-citation 
# mixed-citation
# nlm-citation
# ref
# citation-alternatives
# ref-list 
# xref
# source
# bibr
# collab
# contrib-group
# person-group
# pub-id
# ext-link
# back

rec_credit = ['Parent1_Tag','Parent2_Tag','Parent3_Tag','Parent4_Tag','Parent1_Content','Parent2_Content']
XML_results["rec_credit"] = np.where((XML_results[rec_credit] == "element-citation").any(axis=1) | (XML_results[rec_credit]== "mixed-citation").any(axis=1) | (XML_results[rec_credit]== "nlm-citation").any(axis=1) | (XML_results[rec_credit]== "ref").any(axis=1) | (XML_results[rec_credit]== "citation-alternatives").any(axis=1) | (XML_results[rec_credit]== "ref-list").any(axis=1) | (XML_results[rec_credit]== "xref").any(axis=1) | (XML_results[rec_credit]== "source").any(axis=1) | (XML_results[rec_credit]== "collab").any(axis=1) | (XML_results[rec_credit]== "contrib-group").any(axis=1) | (XML_results[rec_credit]== "person-group").any(axis=1) | (XML_results[rec_credit]== "pub-id").any(axis=1) | (XML_results[rec_credit] == "fn").any(axis=1) | (XML_results[rec_credit]== "fn-group").any(axis=1) | (XML_results[rec_credit]== "ack").any(axis=1) |(XML_results[rec_credit]== "back").any(axis=1) |(XML_results[rec_credit]== "ext-link").any(axis=1) | (XML_results[rec_credit]== "bibr").any(axis=1), "yes", "no")

# %%
# Check new cols

list(XML_results.columns.values)
# Out:
# ['Alias',
#  'Software_Package',
#  'Identifier',
#  'Pub_Year',
#  'DOI',
#  'Journal_Title',
#  'Article_ID',
#  'File_Name',
#  'Parent1_Tag',
#  'Parent2_Tag',
#  'Parent3_Tag',
#  'Parent4_Tag',
#  'Parent1_Content',
#  'Parent2_Content',
#  'Parent3_Content',
#  'Author(s)',
#  'Publisher',
#  'Title',
#  'ref',
#  'ack',
#  'fn',
#  'rec_credit']

# %%
XML_results.to_csv("XML_FINAL_ANALYSIS_082019.csv")

# %% [markdown]
# ## Summary of Results

# %%
XML_alias_per_paper = pd.DataFrame({'count' : XML_results.groupby(["Software_Package","File_Name"])['Alias'].nunique()})
XML_alias_per_paper.to_csv("XML_alias_per_paper_082019.csv")
XML_alias_per_paper
# Out:
#                                      count
# Software_Package File_Name
# AstroBlend       apj_818_2_115.xml       2
# Astropy          aj_148_1_13.xml         4
#                  aj_148_1_14.xml         5
#                  aj_148_3_53.xml         4
#                  aj_148_6_122.xml        4
#                  aj_150_4_118.xml        4
#                  aj_150_4_132.xml        4
#                  aj_150_5_145.xml        4
#                  aj_150_6_179.xml        4
#                  aj_150_6_189.xml        4
#                  aj_151_1_3.xml          1
#                  aj_151_2_41.xml         4
#                  aj_151_3_61.xml         4
#                  aj_151_4_99.xml         4
#                  aj_151_6_158.xml        1
#                  aj_151_6_173.xml        3
#                  aj_152_1_9.xml          1
#                  aj_152_2_40.xml         4
#                  aj_152_3_70.xml         4
#                  aj_152_5_123.xml        4
#                  aj_152_6_154.xml        4
#                  aj_152_6_178.xml        2
#                  aj_152_6_212.xml        1
#                  aj_152_6_228.xml        7
#                  aj_153_1_10.xml         4
#                  aj_153_1_13.xml         4
#                  aj_153_1_3.xml          3
#                  aj_153_2_58.xml         1
#                  aj_153_3_107.xml        6
#                  aj_153_3_116.xml        4
# ...                                    ...
# WCSTools         apj_763_2_96.xml        1
#                  apj_767_1_62.xml        1
#                  apj_770_2_107.xml       2
#                  apj_772_2_126.xml       1
#                  apj_778_1_19.xml        1
#                  apj_778_2_91.xml        2
#                  apj_779_1_42.xml        3
#                  apj_787_1_55.xml        2
#                  apj_789_2_138.xml       1
#                  apj_809_1_17.xml        1
#                  apj_815_2_120.xml       1
#                  apj_818_1_67.xml        2
#                  apj_825_2_151.xml       2
#                  apj_837_1_62.xml        2
#                  apj_846_1_67.xml        1
#                  apj_850_2_155.xml       2
#                  apj_856_2_109.xml       2
#                  apjl_746_1_11.xml       1
#                  apjl_749_1_2.xml        2
#                  apjl_765_1_19.xml       2
#                  apjl_807_1_L2.xml       2
#                  apjs_184_1_172.xml      1
#                  apjs_185_1_85.xml       1
#                  apjs_188_1_75.xml       2
#                  apjs_193_1_12.xml       2
#                  apjs_193_2_26.xml       3
#                  apjs_193_2_28.xml       2
#                  apjs_203_1_2.xml        2
#                  apjs_218_2_29.xml       1
#                  apjs_225_1_11.xml       2
#
# [1527 rows x 1 columns]

# %%
# How many papers did we find for each software package?

XML_results.groupby('Software_Package')['File_Name'].nunique()
# Out:
# Software_Package
# AstroBlend        1
# Astropy         538
# RADMC-3D        214
# SAOImage DS9    341
# Spec2d          304
# Stingray          2
# TARDIS            4
# WCSTools        123
# Name: File_Name, dtype: int64

# %%
# Total number of unique XML files

XML_results.File_Name.nunique()
# Out:
# 1469

# %%
# Date range of all XML files

XML_results.groupby('Pub_Year')['File_Name'].nunique()
# Out:
# Pub_Year
# 1997      1
# 1998      4
# 1999      2
# 2000      2
# 2001      4
# 2002      8
# 2003      7
# 2004     16
# 2005     18
# 2006     31
# 2007     49
# 2008     36
# 2009     63
# 2010     76
# 2011     72
# 2012     94
# 2013     82
# 2014    103
# 2015    160
# 2016    205
# 2017    285
# 2018    151
# Name: File_Name, dtype: int64

# %%
# Date range of all XML files (REVISIT THIS)

XML_results.groupby('Pub_Year')['DOI'].nunique()
# Out:
# Pub_Year
# 1997      1
# 1998      1
# 1999      2
# 2000      2
# 2001      2
# 2002      5
# 2003      6
# 2004     13
# 2005     16
# 2006     24
# 2007     41
# 2008     36
# 2009     63
# 2010     76
# 2011     72
# 2012     94
# 2013     82
# 2014    103
# 2015    160
# 2016    205
# 2017    285
# 2018    151
# Name: DOI, dtype: int64

# %%
# Alias per package

XML_results.groupby('Software_Package')['Alias'].nunique()
# Out:
# Software_Package
# AstroBlend       2
# Astropy         21
# RADMC-3D        18
# SAOImage DS9    21
# Spec2d          22
# Stingray         5
# TARDIS           3
# WCSTools        17
# Name: Alias, dtype: int64

# %%
# Alias per journal (REVISIT THIS)

XML_results.groupby('Journal_Title')['DOI'].nunique()
# Out:
# Journal_Title
# The Astronomical Journal                       176
# The Astrophysical Journal                      979
# The Astrophysical Journal Letters              128
# The Astrophysical Journal Supplement Series    148
# Name: DOI, dtype: int64

# %%
XML_results.groupby('Journal_Title')['DOI'].isna().sum()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-30-30b4c5a3894e> in <module>()
#       1
#       2
# ----> 3 XML_results.groupby('Journal_Title')['DOI'].isna().sum()
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'isna' of 'SeriesGroupBy' objects, try using the 'apply' method

# %%
# Alias per journal

XML_results.groupby('Journal_Title')['File_Name'].nunique()
# Out:
# Journal_Title
# The Astronomical Journal                       214
# The Astrophysical Journal                      979
# The Astrophysical Journal Letters              128
# The Astrophysical Journal Supplement Series    148
# Name: File_Name, dtype: int64

# %%
# Most common identifier per package

XML_alias_paper = pd.DataFrame(XML_results.groupby(['Alias','Software_Package'])['Identifier'].nunique())
XML_alias_paper
# Out:
#   File "<ipython-input-25-45b66a564767>", line 3
#     XML_alias_paper = pd.DataFrame(XML_results.groupby(['Alias','Software_Package'])['Identifier' = 1].nunique())
#                                                                                                   ^
# SyntaxError: invalid syntax

# %%
# Alias per package

XML_results.groupby('Pub_Year')['Alias'].nunique()
XML_alias_paper
# Out:
#                                                                      Identifier
# Alias                                              Software_Package
# 10.1051/0004-6361/201322068                        Astropy                    1
# 10.1051/0004-6361:20031768                         RADMC-3D                   1
# 10.1051/0004-6361:20040017                         RADMC-3D                   1
# 10.1088/0067-0049/208/1/5                          Spec2d                     1
# 10.1093/mnras/stu055                               TARDIS                     1
# 1997ASPC..125..249M                                WCSTools                   1
# 1999ASPC..172..498M                                WCSTools                   1
# 2000ascl.soft03002S                                SAOImage DS9               1
# 2002ASPC..281..169M                                WCSTools                   1
# 2003ASPC..295..489J                                SAOImage DS9               1
# 2004A&A...417..159D                                RADMC-3D                   1
# 2004A&A...417..793P                                RADMC-3D                   1
# 2006ASPC..351..204M                                WCSTools                   1
# 2011ascl.soft08016D                                RADMC-3D                   1
# 2012ascl.soft02015D                                RADMC-3D                   1
# 2012ascl.soft03003C                                Spec2d                     1
# 2013A&A...558A..33A                                Astropy                    1
# 2013ApJS..208....5N                                Spec2d                     1
# AstroPy                                            Astropy                    1
# Astropy                                            Astropy                    1
# Astropy Collaboration                              Astropy                    1
# Astropy Collaboration 2013                         Astropy                    1
# DEEP2 DEIMOS Data Pipeline                         Spec2d                     1
# DEEP2 DEIMOS data pipeline                         Spec2d                     1
# DEEP2 DEIMOS data reduction pipeline               Spec2d                     1
# DEEP2 DEIMOS pipeline                              Spec2d                     1
# DEIMOS pipeline                                    Spec2d                     1
# DS9                                                SAOImage DS9               1
# DS9 Region                                         SAOImage DS9               1
# HENDRICS                                           Stingray                   1
# ...                                                                         ...
# hea&hyphen;www.harvard.edu/RD/saotng               SAOImage DS9               1
# hea&hyphen;www.harvard.edu/saord/ds9               SAOImage DS9               1
# hea-www.harvard.edu/RD/ds9                         SAOImage DS9               1
# hea-www.harvard.edu/saord/funtools/ds9             SAOImage DS9               1
# idlspec2d                                          Spec2d                     1
# imwcs                                              WCSTools                   1
# ita.uni-heidelberg.de/dullemond/software/radmc-3d  RADMC-3D                   1
# ita.uni-heidelberg.de/~dullemond/software/radmc-3d RADMC-3D                   1
# ita.uni-heidelberg.de∼deullemond/software/radmc-3d RADMC-3D                   1
# juno.as.arizona.edu/~cooper/deep/spec2d            Spec2d                     1
# keck.hawaii.edu/inst/deimos/pipeline.html          Spec2d                     1
# radmc                                              RADMC-3D                   1
# radmc-3d                                           RADMC-3D                   1
# radmc3d                                            RADMC-3D                   1
# radmc3dPy                                          RADMC-3D                   1
# saoimage                                           SAOImage DS9               1
# saoimage ds9                                       SAOImage DS9               1
# sdss3.org/svn/repo/idlspec2d                       Spec2d                     1
# sky2xy                                             WCSTools                   1
# spec2d                                             Spec2d                     1
# spectro.princeton.edu/idlspec2d                    Spec2d                     1
# stingray                                           Stingray                   1
# svn.sdss.org/public/repo/manga/mangadrp/tags/v1... Spec2d                     1
# tardis                                             TARDIS                     1
# tdc&hyphen;www.harvard.edu/software/wcstools       WCSTools                   1
# tdc-www.cfa.harvard.edu/software/wcstools          WCSTools                   1
# tdc-www.harvard.edu/software/wcstools              WCSTools                   1
# tdc-www.harvard.edu/wcstools                       WCSTools                   1
# wcstools                                           WCSTools                   1
# xy2sky                                             WCSTools                   1
#
# [109 rows x 1 columns]

# %%
# Total number of unique alias

XML_unique_alias = pd.DataFrame(XML_results.groupby(['Software_Package','Alias'])['Index'].nunique())
#XML_unique_alias.to_csv("XML_unique_alias_082019.csv")
XML_unique_alias
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-24-b967d8af74a8> in <module>()
#       1 # Total number of unique alias
#       2
# ----> 3 XML_unique_alias = pd.DataFrame(XML_results.groupby(['Software_Package','Alias'])['Index'].nunique())
#       4 #XML_unique_alias.to_csv("XML_unique_alias_082019.csv")
#       5 XML_unique_alias
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     273         else:
#     274             if key not in self.obj:
# --> 275                 raise KeyError("Column not found: {key}".format(key=key))
#     276             return self._gotitem(key, ndim=1)
#     277
#
# KeyError: 'Column not found: Index'

# %%
#Alias per paper

XML_alias_paper = pd.DataFrame(XML_results.groupby(['DOI','Software_Package'])['Alias'].nunique())
#XML_alias_paper.to_csv("XML_alias_paper_082019.csv")
XML_alias_paper
# Out:
#                                            Alias
# DOI                      Software_Package
# #VALUE!                  SAOImage DS9          7
#                          Spec2d                4
#                          WCSTools              6
# 10.1086/304882           SAOImage DS9          1
# 10.1086/312617           SAOImage DS9          1
# 10.1086/313204           SAOImage DS9          1
# 10.1086/321561           SAOImage DS9          1
# 10.1086/339572           WCSTools              1
# 10.1086/340936           SAOImage DS9          2
# 10.1086/342702           WCSTools              1
# 10.1086/343127           WCSTools              1
# 10.1086/346233           Spec2d                1
# 10.1086/374040           SAOImage DS9          1
# 10.1086/375528           Spec2d                1
# 10.1086/376406           SAOImage DS9          1
# 10.1086/378977           WCSTools              1
# 10.1086/379887           SAOImage DS9          1
# 10.1086/380120           WCSTools              1
# 10.1086/382125           Spec2d                1
# 10.1086/382676           SAOImage DS9          1
# 10.1086/383084           WCSTools              3
# 10.1086/383531           Spec2d                1
# 10.1086/421463           Spec2d                1
# 10.1086/421696           SAOImage DS9          1
# 10.1086/422187           SAOImage DS9          1
# 10.1086/422818           RADMC-3D              1
# 10.1086/422914           WCSTools              1
# 10.1086/423320           WCSTools              1
# 10.1086/426116           SAOImage DS9          1
# 10.1086/427688           RADMC-3D              1
# ...                                          ...
# 10.3847/2041-8213/aa8771 RADMC-3D              1
# 10.3847/2041-8213/aa905f Astropy               3
# 10.3847/2041-8213/aa90b6 Astropy               4
# 10.3847/2041-8213/aa9110 Astropy               5
# 10.3847/2041-8213/aa9111 Astropy               5
# 10.3847/2041-8213/aa970f Astropy               4
# 10.3847/2041-8213/aa97d5 Astropy               4
# 10.3847/2041-8213/aa991a Astropy               1
# 10.3847/2041-8213/aa9985 SAOImage DS9          1
# 10.3847/2041-8213/aa9a34 Astropy               4
# 10.3847/2041-8213/aa9b7b RADMC-3D              1
# 10.3847/2041-8213/aa9d81 Astropy               4
#                          SAOImage DS9          1
# 10.3847/2041-8213/aa9d85 Astropy               1
# 10.3847/2041-8213/aaa07c Astropy               4
# 10.3847/2041-8213/aaa0c9 Astropy               3
# 10.3847/2041-8213/aaa83b Astropy               4
#                          Stingray              5
# 10.3847/2041-8213/aaa958 Astropy               4
#                          SAOImage DS9          1
# 10.3847/2041-8213/aaaa62 Astropy               4
# 10.3847/2041-8213/aaadb3 Astropy               1
# 10.3847/2041-8213/aab151 Astropy               4
# 10.3847/2041-8213/aab267 Astropy               4
# 10.3847/2041-8213/aab3dc Astropy               4
# 10.3847/2041-8213/aab493 Astropy               1
# 10.3847/2041-8213/aab603 Spec2d                3
# 10.3847/2041-8213/aab61e Astropy               2
# 10.3847/2041-8213/aab6ac Astropy               4
# 10.3847/2041-8213/aabadc Stingray              1
#
# [1491 rows x 1 columns]

# %%
# Identifiers per package

XML_unique_id = pd.DataFrame(XML_results.groupby(['Software_Package','Identifier'])['Index'].nunique())
#XML_unique_id.to_csv("XML_unique_id_082019.csv")
XML_unique_id
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-62-b808180afe47> in <module>()
#       1 # Identifiers per package
#       2
# ----> 3 XML_unique_id = pd.DataFrame(XML_results.groupby(['Software_Package','Identifier'])['Index'].nunique())
#       4 #XML_unique_id.to_csv("XML_unique_id_082019.csv")
#       5 XML_unique_id
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     273         else:
#     274             if key not in self.obj:
# --> 275                 raise KeyError("Column not found: {key}".format(key=key))
#     276             return self._gotitem(key, ndim=1)
#     277
#
# KeyError: 'Column not found: Index'

# %%
# Tag count per parent

XML_unique_tags1 = pd.DataFrame(XML_results.groupby(['Parent1_Tag'])['Index'].nunique())
XML_unique_tags2 = pd.DataFrame(XML_results.groupby(['Parent2_Tag'])['Index'].nunique())
XML_unique_tags3 = pd.DataFrame(XML_results.groupby(['Parent3_Tag'])['Index'].nunique())
XML_unique_tags4 = pd.DataFrame(XML_results.groupby(['Parent4_Tag'])['Index'].nunique())

XML_unique_tags1.to_csv("XML_unique_tags1_082019.csv")
XML_unique_tags2.to_csv("XML_unique_tags2_082019.csv")
XML_unique_tags3.to_csv("XML_unique_tags3_082019.csv")
XML_unique_tags4.to_csv("XML_unique_tags4_082019.csv")

# %%
#Tags per paper

XML_tags_paper1 = pd.DataFrame(XML_results.groupby(['File_Name'])['Parent1_Tag'].nunique())
XML_tags_paper2 = pd.DataFrame(XML_results.groupby(['File_Name'])['Parent2_Tag'].nunique())
XML_tags_paper3 = pd.DataFrame(XML_results.groupby(['File_Name'])['Parent3_Tag'].nunique())
XML_tags_paper4 = pd.DataFrame(XML_results.groupby(['File_Name'])['Parent4_Tag'].nunique())

XML_tags_paper1.to_csv("XML_tags_paper1_082019.csv")
XML_tags_paper2.to_csv("XML_tags_paper2_082019.csv")
XML_tags_paper3.to_csv("XML_tags_paper3_082019.csv")
XML_tags_paper4.to_csv("XML_tags_paper4_082019.csv")

# %%
#Tags per package

XML_unique_tags_package1 = pd.DataFrame(XML_results.groupby(['Software_Package', 'Parent1_Tag'])['Index'].nunique())
XML_unique_tags_package2 = pd.DataFrame(XML_results.groupby(['Software_Package', 'Parent2_Tag'])['Index'].nunique())
XML_unique_tags_package3 = pd.DataFrame(XML_results.groupby(['Software_Package', 'Parent3_Tag'])['Index'].nunique())
XML_unique_tags_package4 = pd.DataFrame(XML_results.groupby(['Software_Package', 'Parent4_Tag'])['Index'].nunique())

XML_unique_tags_package1.to_csv("XML_unique_tags_package1_082019.csv")
XML_unique_tags_package2.to_csv("XML_unique_tags_package2_082019.csv")
XML_unique_tags_package3.to_csv("XML_unique_tags_package3_082019.csv")
XML_unique_tags_package4.to_csv("XML_unique_tags_package4_082019.csv")

# %%
# Unique files for each alias per year
# Is this useful?

XML_unique_alias_year = pd.DataFrame(XML_results.groupby(['Alias', 'Pub_Year'])['File_Name'].nunique())
#XML_unique_alias_year.to_csv("XML_unique_alias_year_082019.csv")
XML_unique_alias_year
# Out:
#                                                        File_Name
# Alias                                        Pub_Year
# 10.1051/0004-6361/201322068                  2013              2
#                                              2014             35
#                                              2015             53
#                                              2016             91
#                                              2017            165
#                                              2018            103
# 10.1051/0004-6361:20031768                   2009             13
#                                              2010             17
#                                              2011             12
#                                              2012             18
#                                              2013              7
#                                              2014              4
#                                              2015              8
#                                              2016              8
#                                              2017              6
#                                              2018              3
# 10.1051/0004-6361:20040017                   2009              1
#                                              2010              2
#                                              2011              2
#                                              2012              2
#                                              2014              2
#                                              2015              2
# 10.1088/0067-0049/208/1/5                    2013              5
#                                              2014             23
#                                              2015             32
#                                              2016             29
#                                              2017             26
#                                              2018              9
# 10.1093/mnras/stu055                         2015              1
#                                              2016              2
# ...                                                          ...
# tdc&hyphen;www.harvard.edu/software/wcstools 2004              2
#                                              2005              2
#                                              2007              2
#                                              2008              1
# tdc-www.cfa.harvard.edu/software/wcstools    2007              1
#                                              2009              1
# tdc-www.harvard.edu/software/wcstools        2009              1
#                                              2010              4
#                                              2011              4
#                                              2017              1
# tdc-www.harvard.edu/wcstools                 2011              1
#                                              2012              4
#                                              2013              3
#                                              2015              1
#                                              2016              1
#                                              2017              1
# wcstools                                     2004              1
#                                              2006              1
#                                              2009              2
#                                              2010              4
#                                              2011              2
#                                              2012              2
#                                              2013              2
#                                              2016              1
# xy2sky                                       2007              1
#                                              2008              1
#                                              2010              1
#                                              2011              1
#                                              2012              3
#                                              2013              1
#
# [496 rows x 1 columns]

# %%
# Total number of unique papers with software aliases by year

XML_unique_paper_year = pd.DataFrame(XML_results.groupby(['Pub_Year'])['File_Name'].nunique())
#XML_unique_paper_year.to_csv("XML_unique_paper_year_082019.csv")
XML_unique_paper_year
# Out:
#           File_Name
# Pub_Year
# 1997              1
# 1998              4
# 1999              2
# 2000              2
# 2001              4
# 2002              8
# 2003              7
# 2004             16
# 2005             18
# 2006             31
# 2007             49
# 2008             36
# 2009             63
# 2010             76
# 2011             72
# 2012             94
# 2013             82
# 2014            103
# 2015            160
# 2016            205
# 2017            285
# 2018            151

# %%
# Total number of unique papers with software aliases in the references section by year


XML_unique_paper_ref_year = pd.DataFrame(XML_results.groupby(['ref', 'Pub_Year'])['File_Name'].nunique())
#XML_unique_paper_ref_year.to_csv("XML_unique_paper_ref_year_082019.csv")
XML_unique_paper_ref_year
# Out:
#               File_Name
# ref Pub_Year
# no  1997              1
#     1998              4
#     1999              2
#     2000              2
#     2001              3
#     2002              8
#     2003              7
#     2004             13
#     2005             17
#     2006             30
#     2007             46
#     2008             32
#     2009             56
#     2010             66
#     2011             61
#     2012             77
#     2013             69
#     2014             84
#     2015            133
#     2016            181
#     2017            261
#     2018            140
# yes 2001              2
#     2002              2
#     2003              1
#     2004              5
#     2005              6
#     2006              6
#     2007              6
#     2008              7
#     2009             33
#     2010             42
#     2011             45
#     2012             50
#     2013             44
#     2014             78
#     2015            133
#     2016            163
#     2017            247
#     2018            133

# %%
# Trends over time for each AAS Journal



XML_journal_year = pd.DataFrame(XML_results.groupby(['Journal_Title', 'Pub_Year'])['File_Name'].nunique())
#XML_journal_year.to_csv("XML_journal_year_082019.csv")
XML_journal_year
# Out:
#                                                       File_Name
# Journal_Title                               Pub_Year
# The Astronomical Journal                    1998              4
#                                             1999              1
#                                             2000              1
#                                             2001              3
#                                             2002              4
#                                             2003              2
#                                             2004              4
#                                             2005              3
#                                             2006              8
#                                             2007              9
#                                             2008              3
#                                             2009              6
#                                             2010             22
#                                             2011             10
#                                             2012             11
#                                             2013             10
#                                             2014              9
#                                             2015             12
#                                             2016             23
#                                             2017             46
#                                             2018             23
# The Astrophysical Journal                   1997              1
#                                             2001              1
#                                             2002              4
#                                             2003              5
#                                             2004              7
#                                             2005             12
#                                             2006             20
#                                             2007             34
#                                             2008             22
# ...                                                         ...
# The Astrophysical Journal Letters           2004              1
#                                             2005              1
#                                             2006              2
#                                             2007              4
#                                             2008              4
#                                             2010              3
#                                             2011              5
#                                             2012              9
#                                             2013              5
#                                             2014             12
#                                             2015             14
#                                             2016             22
#                                             2017             32
#                                             2018             13
# The Astrophysical Journal Supplement Series 1999              1
#                                             2004              4
#                                             2005              2
#                                             2006              1
#                                             2007              2
#                                             2008              7
#                                             2009              5
#                                             2010              7
#                                             2011             18
#                                             2012              7
#                                             2013             12
#                                             2014              9
#                                             2015             18
#                                             2016             20
#                                             2017             16
#                                             2018             19
#
# [71 rows x 1 columns]

# %%
# Which software packages showed up in which journals

XML_package_per_journal = pd.DataFrame(XML_results.groupby(['Journal_Title', 'Software_Package'])['File_Name'].nunique())
XML_package_per_journal.to_csv("XML_package_per_journal_082019.csv")
XML_package_per_journal
# Out:
#                                                               File_Name
# Journal_Title                               Software_Package
# The Astronomical Journal                    Astropy                  76
#                                             RADMC-3D                  7
#                                             SAOImage DS9             68
#                                             Spec2d                   25
#                                             WCSTools                 43
# The Astrophysical Journal                   AstroBlend                1
#                                             Astropy                 364
#                                             RADMC-3D                168
#                                             SAOImage DS9            196
#                                             Spec2d                  229
#                                             TARDIS                    3
#                                             WCSTools                 59
# The Astrophysical Journal Letters           Astropy                  62
#                                             RADMC-3D                 27
#                                             SAOImage DS9             15
#                                             Spec2d                   21
#                                             Stingray                  2
#                                             WCSTools                  7
# The Astrophysical Journal Supplement Series Astropy                  36
#                                             RADMC-3D                 12
#                                             SAOImage DS9             62
#                                             Spec2d                   29
#                                             TARDIS                    1
#                                             WCSTools                 14

# %%
# Total number of articles with software mentions (1527) per journal

XML_articles_mentions_per_journal = pd.DataFrame(XML_results.groupby(['Journal_Title','Software_Package'])['File_Name'].nunique())
XML_articles_mentions_per_journal.to_csv("XML_articles_mentions_per_journal_082019.csv")
XML_articles_mentions_per_journal
# Out:
#                                                               File_Name
# Journal_Title                               Software_Package
# The Astronomical Journal                    Astropy                  76
#                                             RADMC-3D                  7
#                                             SAOImage DS9             68
#                                             Spec2d                   25
#                                             WCSTools                 43
# The Astrophysical Journal                   AstroBlend                1
#                                             Astropy                 364
#                                             RADMC-3D                168
#                                             SAOImage DS9            196
#                                             Spec2d                  229
#                                             TARDIS                    3
#                                             WCSTools                 59
# The Astrophysical Journal Letters           Astropy                  62
#                                             RADMC-3D                 27
#                                             SAOImage DS9             15
#                                             Spec2d                   21
#                                             Stingray                  2
#                                             WCSTools                  7
# The Astrophysical Journal Supplement Series Astropy                  36
#                                             RADMC-3D                 12
#                                             SAOImage DS9             62
#                                             Spec2d                   29
#                                             TARDIS                    1
#                                             WCSTools                 14

# %%
# Which tags were associated with each software package?

XML_tags1 = pd.DataFrame({'tags' : XML_results.groupby( [ "Software_Package", "Parent1_Tag"] ).size()}).reset_index()
XML_tags2 = pd.DataFrame({'tags' : XML_results.groupby( [ "Software_Package", "Parent2_Tag"] ).size()}).reset_index()
XML_tags3 = pd.DataFrame({'tags' : XML_results.groupby( [ "Software_Package", "Parent3_Tag"] ).size()}).reset_index()
XML_tags4 = pd.DataFrame({'tags' : XML_results.groupby( [ "Software_Package", "Parent4_Tag"] ).size()}).reset_index()
XML_all_tags = [XML_tags1, XML_tags2, XML_tags3, XML_tags4]
XML_all_tags = pd.concat(XML_all_tags)
# write tags to csv
XML_all_tags.to_csv("XML_all_tags_082019.csv")
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
# Parent 1 tags per package

XML_tags1 = pd.DataFrame({'Count' : XML_results.groupby( [ "Software_Package", "Parent1_Tag"] ).size()})
XML_tags1.to_csv("XML_tags1_082019.csv")
XML_tags1
# Out:
#                                 Count
# Software_Package Parent1_Tag
# AstroBlend       ext-link           1
#                  sc                 1
# Astropy          collab           389
#                  comment           41
#                  conf-name          1
#                  disp-formula       3
#                  ext-link         576
#                  institution        1
#                  italic            14
#                  monospace        108
#                  p                648
#                  pub-id           405
#                  sans-serif         2
#                  sc                22
#                  source             6
#                  surname            9
#                  td                 1
#                  tex-math           3
#                  year               1
# RADMC-3D         article-title     19
#                  comment            5
#                  ext-link         267
#                  fpage              1
#                  italic             3
#                  monospace         50
#                  p                343
#                  pub-id            23
#                  sc                42
#                  source            13
#                  td                 4
# ...                               ...
# SAOImage DS9     monospace          5
#                  p                368
#                  sc                 4
#                  source             1
#                  title              1
# Spec2d           article-id         1
#                  article-title      6
#                  comment            4
#                  ext-link         253
#                  fpage              1
#                  italic            58
#                  monospace        159
#                  p                181
#                  pub-id            90
#                  sc                24
#                  source            26
#                  sub                2
# Stingray         ext-link           2
#                  monospace          5
#                  p                  4
#                  source             1
# TARDIS           p                  8
#                  pub-id             4
#                  sc                 5
# WCSTools         ext-link          75
#                  italic            26
#                  monospace         19
#                  p                109
#                  sc                 3
#                  tex-math           1
#
# [64 rows x 1 columns]

# %%
# Parent 2 tags per package

XML_tags2 = pd.DataFrame({'Count' : XML_results.groupby( [ "Software_Package", "Parent2_Tag"] ).size()})
XML_tags2.to_csv("XML_tags2_082019.csv")
XML_tags2
# Out:
#                                    Count
# Software_Package Parent2_Tag
# AstroBlend       p                     2
# Astropy          abstract              1
#                  ack                 549
#                  aff                   1
#                  app                   4
#                  disp-formula          3
#                  element-citation    852
#                  fn                    4
#                  list-item             6
#                  name                  9
#                  nlm-citation         88
#                  p                   239
#                  person-group        388
#                  sec                  84
#                  td                    1
#                  tr                    1
# RADMC-3D         abstract              3
#                  ack                  21
#                  app                  21
#                  article-title         2
#                  caption              42
#                  comment               6
#                  element-citation     88
#                  fn                    5
#                  list-item             3
#                  nlm-citation        173
#                  p                   155
#                  sec                 251
#                  tr                    4
# SAOImage DS9     ack                 125
# ...                                  ...
# Spec2d           ack                  35
#                  app                   2
#                  article-meta          1
#                  article-title         2
#                  caption               6
#                  comment               3
#                  element-citation    214
#                  fn                   12
#                  nlm-citation         91
#                  oasis:entry           2
#                  p                   309
#                  sec                 125
#                  title                 2
# Stingray         element-citation      1
#                  fn                    1
#                  p                     7
#                  sec                   3
# TARDIS           element-citation      4
#                  p                     5
#                  sec                   8
# WCSTools         ack                   2
#                  app                   4
#                  comment               1
#                  element-citation     10
#                  fn                    5
#                  inline-formula        1
#                  list-item             2
#                  nlm-citation         28
#                  p                    84
#                  sec                  96
#
# [69 rows x 1 columns]

# %%
# Parent 3 tags per package

XML_tags3 = pd.DataFrame({'Count' : XML_results.groupby( [ "Software_Package", "Parent3_Tag"] ).size()})
XML_tags3.to_csv("XML_tags3_082019.csv")
XML_tags3
# Out:
#                                    Count
# Software_Package Parent3_Tag
# AstroBlend       fn                    1
#                  sec                   1
# Astropy          abstract              2
#                  ack                 114
#                  app                   5
#                  app-group             4
#                  article              31
#                  article-meta          1
#                  back                549
#                  caption               1
#                  contrib-group         1
#                  element-citation    349
#                  fn                   52
#                  list                  6
#                  list-item             1
#                  nlm-citation         39
#                  p                     7
#                  person-group          9
#                  ref                 940
#                  sec                 117
#                  tbody                 1
#                  tr                    1
# RADMC-3D         abstract              1
#                  ack                   8
#                  app                   4
#                  app-group            21
#                  article              90
#                  article-meta          3
#                  back                 21
#                  caption               6
# ...                                  ...
# Spec2d           front                 1
#                  list-item            17
#                  nlm-citation          2
#                  oasis:row             2
#                  p                     4
#                  ref                 305
#                  sec                 305
#                  table-wrap-foot       1
# Stingray         article               1
#                  fn                    2
#                  p                     1
#                  ref                   1
#                  sec                   7
# TARDIS           article               7
#                  caption               1
#                  ref                   4
#                  sec                   5
# WCSTools         ack                   8
#                  app                   1
#                  app-group             4
#                  article              27
#                  back                  2
#                  element-citation      1
#                  fn                   33
#                  fn-group              3
#                  list                  2
#                  list-item             1
#                  p                     3
#                  ref                  38
#                  sec                 110
#
# [101 rows x 1 columns]

# %%
# Parent 4 tags per package

XML_tags4 = pd.DataFrame({'Count' : XML_results.groupby( [ "Software_Package", "Parent4_Tag"] ).size()})
XML_tags4.to_csv("XML_tags4_082019.csv")
XML_tags4
# Out:
#                                    Count
# Software_Package Parent4_Tag
# AstroBlend       p                     1
#                  sec                   1
# Astropy          app-group             5
#                  article             619
#                  article-meta          3
#                  back                118
#                  body                 31
#                  element-citation      7
#                  fig                   1
#                  front                 1
#                  list                  1
#                  nlm-citation          2
#                  p                    58
#                  ref                 388
#                  ref-list            940
#                  sec                  54
#                  table                 1
#                  tbody                 1
# RADMC-3D         app                   6
#                  app-group             4
#                  article             188
#                  article-meta          1
#                  back                 29
#                  body                 90
#                  fig                   5
#                  front                 3
#                  list                  1
#                  p                    57
#                  ref                   8
#                  ref-list            261
# ...                                  ...
# Spec2d           front                 1
#                  list                 17
#                  oasis:tbody           2
#                  p                    57
#                  ref                   5
#                  ref-list            305
#                  sec                 194
#                  table-wrap            1
#                  table-wrap-foot       2
# Stingray         article               2
#                  body                  1
#                  p                     2
#                  ref-list              1
#                  sec                   6
# TARDIS           article               1
#                  body                  7
#                  fig                   1
#                  ref-list              4
#                  sec                   4
# WCSTools         ack                   1
#                  app-group             1
#                  article              76
#                  back                 12
#                  body                 27
#                  fn-group             12
#                  list                  1
#                  p                    23
#                  ref                   1
#                  ref-list             38
#                  sec                  41
#
# [87 rows x 1 columns]

# %%
# AstroBlend
AstroBlend_Tags = XML_all_tags.loc[XML_all_tags['Software_Package'].str.contains("AstroBlend")]
AstroBlend_Tags = pd.concat([AstroBlend_Tags['Parent1_Tag'], AstroBlend_Tags['Parent2_Tag'], AstroBlend_Tags['Parent3_Tag'], AstroBlend_Tags['Parent4_Tag']]).unique()
AstroBlend_Tags = np.ndarray.tolist(AstroBlend_Tags)
AstroBlend_Tags = pd.DataFrame(AstroBlend_Tags, columns = ["AstroBlend_XML_Tags"])
AstroBlend_Tags = AstroBlend_Tags[AstroBlend_Tags.AstroBlend_XML_Tags.notnull()]
AstroBlend_Tags = AstroBlend_Tags.sort_values(by=['AstroBlend_XML_Tags']).reset_index(drop=True)
# write tags to csv
AstroBlend_Tags.to_csv("AstroBlend_Tags_082019.csv")
AstroBlend_Tags
# Out:
#   AstroBlend_XML_Tags
# 0            ext-link
# 1                  fn
# 2                   p
# 3                  sc
# 4                 sec

# %%
# AstroPy
AstroPy_Tags = XML_all_tags.loc[XML_all_tags['Software_Package'].str.contains("AstroPy")]
AstroPy_Tags = pd.concat([AstroPy_Tags['Parent1_Tag'], AstroPy_Tags['Parent2_Tag'], AstroPy_Tags['Parent3_Tag'], AstroPy_Tags['Parent4_Tag']]).unique()
AstroPy_Tags = np.ndarray.tolist(AstroPy_Tags)
AstroPy_Tags = pd.DataFrame(AstroPy_Tags, columns = ["AstroPy_XML_Tags"])
AstroPy_Tags = AstroPy_Tags[AstroPy_Tags.AstroPy_XML_Tags.notnull()]
AstroPy_Tags = AstroPy_Tags.sort_values(by=['AstroPy_XML_Tags']).reset_index(drop=True)
# write tags to csv
AstroPy_Tags.to_csv("AstroPy_Tags_082019.csv")
AstroPy_Tags
# Out:
# Empty DataFrame
# Columns: [AstroPy_XML_Tags]
# Index: []

# %%
# RADMC-3D
RADMC3D_Tags = XML_all_tags.loc[XML_all_tags['Software_Package'].str.contains("RADMC-3D")]
RADMC3D_Tags = pd.concat([RADMC3D_Tags['Parent1_Tag'], RADMC3D_Tags['Parent2_Tag'], RADMC3D_Tags['Parent3_Tag'], RADMC3D_Tags['Parent4_Tag']]).unique()
RADMC3D_Tags = np.ndarray.tolist(RADMC3D_Tags)
RADMC3D_Tags = pd.DataFrame(RADMC3D_Tags, columns = ["RADMC3D_XML_Tags"])
RADMC3D_Tags = RADMC3D_Tags[RADMC3D_Tags.RADMC3D_XML_Tags.notnull()]
RADMC3D_Tags = RADMC3D_Tags.sort_values(by=['RADMC3D_XML_Tags']).reset_index(drop=True)
# write tags to csv
RADMC3D_Tags.to_csv("RADMC3D_Tags_082019.csv")
RADMC3D_Tags
# Out:
#     RADMC3D_XML_Tags
# 0           abstract
# 1                ack
# 2                app
# 3          app-group
# 4            article
# 5       article-meta
# 6      article-title
# 7               back
# 8               body
# 9            caption
# 10           comment
# 11  element-citation
# 12          ext-link
# 13               fig
# 14         fig-group
# 15                fn
# 16             fpage
# 17             front
# 18            italic
# 19              list
# 20         list-item
# 21         monospace
# 22      nlm-citation
# 23                 p
# 24            pub-id
# 25               ref
# 26          ref-list
# 27                sc
# 28               sec
# 29            source
# 30             table
# 31        table-wrap
# 32   table-wrap-foot
# 33             tbody
# 34                td
# 35             title
# 36                tr
# 37            volume

# %%
# DS9
SAOImageDS9_Tags = XML_all_tags.loc[XML_all_tags['Software_Package'].str.contains("SAOImage DS9")]
SAOImageDS9_Tags = pd.concat([SAOImageDS9_Tags['Parent1_Tag'], SAOImageDS9_Tags['Parent2_Tag'], SAOImageDS9_Tags['Parent3_Tag'], SAOImageDS9_Tags['Parent4_Tag']]).unique()
SAOImageDS9_Tags = np.ndarray.tolist(SAOImageDS9_Tags)
SAOImageDS9_Tags = pd.DataFrame(SAOImageDS9_Tags, columns = ["SAOImageDS9_XML_Tags"])
SAOImageDS9_Tags = SAOImageDS9_Tags[SAOImageDS9_Tags.SAOImageDS9_XML_Tags.notnull()]
SAOImageDS9_Tags = SAOImageDS9_Tags.sort_values(by=['SAOImageDS9_XML_Tags']).reset_index(drop=True)
# write tags to csv
SAOImageDS9_Tags.to_csv("SAOImageDS9_Tags_082019.csv")
SAOImageDS9_Tags
# Out:
#    SAOImageDS9_XML_Tags
# 0                   ack
# 1                   app
# 2             app-group
# 3               article
# 4                  back
# 5                  body
# 6               caption
# 7      element-citation
# 8              ext-link
# 9                   fig
# 10            fig-group
# 11                   fn
# 12             fn-group
# 13               italic
# 14                 list
# 15            list-item
# 16            monospace
# 17         nlm-citation
# 18                    p
# 19                  ref
# 20             ref-list
# 21                   sc
# 22                  sec
# 23               source
# 24           table-wrap
# 25      table-wrap-foot
# 26                title

# %%
# Spec2d
Spec2d_Tags = XML_all_tags.loc[XML_all_tags['Software_Package'].str.contains("Spec2d")]
Spec2d_Tags = pd.concat([Spec2d_Tags['Parent1_Tag'], Spec2d_Tags['Parent2_Tag'], Spec2d_Tags['Parent3_Tag'], Spec2d_Tags['Parent4_Tag']]).unique()
Spec2d_Tags = np.ndarray.tolist(Spec2d_Tags)
Spec2d_Tags = pd.DataFrame(Spec2d_Tags, columns = ["Spec2d_XML_Tags"])
Spec2d_Tags = Spec2d_Tags[Spec2d_Tags.Spec2d_XML_Tags.notnull()]
Spec2d_Tags = Spec2d_Tags.sort_values(by=['Spec2d_XML_Tags']).reset_index(drop=True)
# write tags to csv
Spec2d_Tags.to_csv("Spec2d_Tags_082019.csv")
Spec2d_Tags
# Out:
#      Spec2d_XML_Tags
# 0           abstract
# 1                ack
# 2                app
# 3          app-group
# 4            article
# 5         article-id
# 6       article-meta
# 7      article-title
# 8               back
# 9               body
# 10           caption
# 11           comment
# 12  element-citation
# 13          ext-link
# 14               fig
# 15         fig-group
# 16                fn
# 17          fn-group
# 18             fpage
# 19             front
# 20            italic
# 21              list
# 22         list-item
# 23         monospace
# 24      nlm-citation
# 25       oasis:entry
# 26         oasis:row
# 27       oasis:tbody
# 28                 p
# 29            pub-id
# 30               ref
# 31          ref-list
# 32                sc
# 33               sec
# 34            source
# 35               sub
# 36        table-wrap
# 37   table-wrap-foot
# 38             title

# %%
# Stingray
Stingray_Tags = XML_all_tags.loc[XML_all_tags['Software_Package'].str.contains("Stingray")]
Stingray_Tags = pd.concat([Stingray_Tags['Parent1_Tag'], Stingray_Tags['Parent2_Tag'], Stingray_Tags['Parent3_Tag'], Stingray_Tags['Parent4_Tag']]).unique()
Stingray_Tags = np.ndarray.tolist(Stingray_Tags)
Stingray_Tags = pd.DataFrame(Stingray_Tags, columns = ["Stingray_XML_Tags"])
Stingray_Tags = Stingray_Tags[Stingray_Tags.Stingray_XML_Tags.notnull()]
Stingray_Tags = Stingray_Tags.sort_values(by=['Stingray_XML_Tags']).reset_index(drop=True)
# write tags to csv
Stingray_Tags.to_csv("Stingray_Tags_082019.csv")
Stingray_Tags
# Out:
#    Stingray_XML_Tags
# 0            article
# 1               body
# 2   element-citation
# 3           ext-link
# 4                 fn
# 5          monospace
# 6                  p
# 7                ref
# 8           ref-list
# 9                sec
# 10            source

# %%
# tardis
TARDIS_Tags = XML_all_tags.loc[XML_all_tags['Software_Package'].str.contains("TARDIS")]
TARDIS_Tags = pd.concat([TARDIS_Tags['Parent1_Tag'], TARDIS_Tags['Parent2_Tag'], TARDIS_Tags['Parent3_Tag'], TARDIS_Tags['Parent4_Tag']]).unique()
TARDIS_Tags = np.ndarray.tolist(TARDIS_Tags)
TARDIS_Tags = pd.DataFrame(TARDIS_Tags, columns = ["TARDIS_XML_Tags"])
TARDIS_Tags = TARDIS_Tags[TARDIS_Tags.TARDIS_XML_Tags.notnull()]
TARDIS_Tags = TARDIS_Tags.sort_values(by=['TARDIS_XML_Tags']).reset_index(drop=True)
# write tags to csv
TARDIS_Tags.to_csv("TARDIS_Tags_082019.csv")
TARDIS_Tags
# Out:
#      TARDIS_XML_Tags
# 0            article
# 1               body
# 2            caption
# 3   element-citation
# 4                fig
# 5                  p
# 6             pub-id
# 7                ref
# 8           ref-list
# 9                 sc
# 10               sec

# %%
# wcs tools
WCSTools_Tags = XML_all_tags.loc[XML_all_tags['Software_Package'].str.contains("WCSTools")]
WCSTools_Tags = pd.concat([WCSTools_Tags['Parent1_Tag'], WCSTools_Tags['Parent2_Tag'], WCSTools_Tags['Parent3_Tag'], WCSTools_Tags['Parent4_Tag']]).unique()
WCSTools_Tags = np.ndarray.tolist(WCSTools_Tags)
WCSTools_Tags = pd.DataFrame(WCSTools_Tags, columns = ["WCSTools_XML_Tags"])
WCSTools_Tags = WCSTools_Tags[WCSTools_Tags.WCSTools_XML_Tags.notnull()]
WCSTools_Tags = WCSTools_Tags.sort_values(by=['WCSTools_XML_Tags']).reset_index(drop=True)
# write tags to csv
WCSTools_Tags.to_csv("WCSTools_Tags_082019.csv")
WCSTools_Tags
# Out:
#    WCSTools_XML_Tags
# 0                ack
# 1                app
# 2          app-group
# 3            article
# 4               back
# 5               body
# 6            comment
# 7   element-citation
# 8           ext-link
# 9                 fn
# 10          fn-group
# 11    inline-formula
# 12            italic
# 13              list
# 14         list-item
# 15         monospace
# 16      nlm-citation
# 17                 p
# 18               ref
# 19          ref-list
# 20                sc
# 21               sec
# 22          tex-math

# %%
# Proportion of articles with aliases in refrences
XML_all_refs = XML_results.loc[XML_results['ref'] == "yes"]
XML_ref_proportion = XML_all_refs.groupby('Software_Package')['File_Name'].nunique()/XML_results.groupby('Software_Package')['File_Name'].nunique()
XML_ref_proportion
# Out:
# Software_Package
# AstroBlend      1.000000
# Astropy         0.907063
# RADMC-3D        0.883178
# SAOImage DS9    0.299120
# Spec2d          0.631579
# Stingray        0.500000
# TARDIS          1.000000
# WCSTools        0.544715
# Name: File_Name, dtype: float64

# %%
# Total number of unique papers with software aliases in the references section

XML_all_refs = XML_results.loc[XML_results['ref'] == "yes"]
XML_ref_count = XML_all_refs.groupby('Software_Package')['File_Name'].nunique()
XML_ref_count.to_csv("XML_ref_count_082019.csv")
XML_ref_count
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """
# Software_Package
# AstroBlend        1
# Astropy         488
# RADMC-3D        189
# SAOImage DS9    102
# Spec2d          192
# Stingray          1
# TARDIS            4
# WCSTools         67
# Name: File_Name, dtype: int64

# %%
# How many unique aliases were used in the references for each package?
print (XML_all_refs.groupby('Software_Package')['Alias'].nunique())
# Out:
# Software_Package
# AstroBlend       1
# Astropy         17
# RADMC-3D        16
# SAOImage DS9    10
# Spec2d          15
# Stingray         3
# TARDIS           1
# WCSTools        10
# Name: Alias, dtype: int64

# %%
# Which aliases were used in the papers with aliases in references? Write results to csv
XML_ref_aliases = pd.DataFrame({'ref_count' : XML_all_refs.groupby(['Software_Package', 'Alias', 'Identifier'])['File_Name'].nunique()}).reset_index()
XML_ref_aliases.to_csv("XML_ref_aliases_082019.csv")
XML_ref_aliases
# Out:
#    Software_Package                                              Alias  \
# 0        AstroBlend                                     astroblend.com
# 1           Astropy                        10.1051/0004-6361/201322068
# 2           Astropy                                2013A&A...558A..33A
# 3           Astropy                                            Astropy
# 4           Astropy                              Astropy Collaboration
# 5           Astropy                         Astropy Collaboration 2013
# 6           Astropy                                            astropy
# 7           Astropy                                        astropy.org
# 8           Astropy                                  astropy/astroplan
# 9           Astropy                                 astropy/astroquery
# 10          Astropy                                  astropy/halotools
# 11          Astropy                                  astropy/photutils
# 12          Astropy                doi.org/10.1051/0004-6361/201322068
# 13          Astropy                       github.com/astropy/astroplan
# 14          Astropy                      github.com/astropy/astroquery
# 15          Astropy                    github.com/astropy/astroscrappy
# 16          Astropy                       github.com/astropy/halotools
# 17          Astropy                       github.com/astropy/photutils
# 18         RADMC-3D                         10.1051/0004-6361:20031768
# 19         RADMC-3D                         10.1051/0004-6361:20040017
# 20         RADMC-3D                                2004A&A...417..159D
# 21         RADMC-3D                                2004A&A...417..793P
# 22         RADMC-3D                                2011ascl.soft08016D
# 23         RADMC-3D                                2012ascl.soft02015D
# 24         RADMC-3D                                           RADMC-3D
# 25         RADMC-3D                                            RADMC3D
# 26         RADMC-3D                                      ascl:1202.015
# 27         RADMC-3D                        dullemond/software/radmc-3d
# 28         RADMC-3D  ita.uni-heidelberg.de/dullemond/software/radmc-3d
# 29         RADMC-3D  ita.uni-heidelberg.de/~dullemond/software/radm...
# ..              ...                                                ...
# 43     SAOImage DS9             hea-www.harvard.edu/saord/funtools/ds9
# 44           Spec2d                          10.1088/0067-0049/208/1/5
# 45           Spec2d                                2012ascl.soft03003C
# 46           Spec2d                                2013ApJS..208....5N
# 47           Spec2d                                             Spec2d
# 48           Spec2d                                      ascl:1203.003
# 49           Spec2d             astro.berkeley.edu/~cooper/deep/spec2d
# 50           Spec2d            astron.berkeley.edu/~cooper/deep/spec2d
# 51           Spec2d                           deep.berkeley.edu/spec2d
# 52           Spec2d                             deep.ps.uci.edu/spec2d
# 53           Spec2d            juno.as.arizona.edu/~cooper/deep/spec2d
# 54           Spec2d          keck.hawaii.edu/inst/deimos/pipeline.html
# 55           Spec2d                       sdss3.org/svn/repo/idlspec2d
# 56           Spec2d                                             spec2d
# 57           Spec2d                    spectro.princeton.edu/idlspec2d
# 58           Spec2d  svn.sdss.org/public/repo/manga/mangadrp/tags/v...
# 59         Stingray                                           Stingray
# 60         Stingray                github.com/StingraySoftware/HENDRIC
# 61         Stingray              github.com/StingraySoftware/notebooks
# 62           TARDIS                               10.1093/mnras/stu055
# 63         WCSTools                                1997ASPC..125..249M
# 64         WCSTools                                1999ASPC..172..498M
# 65         WCSTools                                2002ASPC..281..169M
# 66         WCSTools                                2006ASPC..351..204M
# 67         WCSTools        cfa&hyphen;ftp.harvard.edu/pub/gsc/WCSTools
# 68         WCSTools       tdc&hyphen;www.harvard.edu/software/wcstools
# 69         WCSTools          tdc-www.cfa.harvard.edu/software/wcstools
# 70         WCSTools              tdc-www.harvard.edu/software/wcstools
# 71         WCSTools                       tdc-www.harvard.edu/wcstools
# 72         WCSTools                                           wcstools
#
#    Identifier  ref_count
# 0           0          1
# 1           1        449
# 2           1        441
# 3           0          6
# 4           0        433
# 5           0          1
# 6           0          2
# 7           0         73
# 8           0          1
# 9           0          2
# 10          0          1
# 11          0          3
# 12          1          2
# 13          0          1
# 14          0          1
# 15          0          2
# 16          0          1
# 17          0          1
# 18          1         96
# 19          1         11
# 20          1         96
# 21          1         11
# 22          1          1
# 23          1          8
# 24          0         34
# 25          0          5
# 26          1          2
# 27          0          8
# 28          0         11
# 29          0         37
# ..        ...        ...
# 43          0          1
# 44          1        123
# 45          1         22
# 46          1        123
# 47          0          1
# 48          1          9
# 49          0         22
# 50          0          7
# 51          0          7
# 52          0          3
# 53          0          1
# 54          0          5
# 55          0          4
# 56          0         34
# 57          0         12
# 58          0          1
# 59          0          1
# 60          0          1
# 61          0          1
# 62          1          4
# 63          1         11
# 64          1         10
# 65          1         13
# 66          1          4
# 67          0          3
# 68          0          8
# 69          0          2
# 70          0         10
# 71          0         11
# 72          0          2
#
# [73 rows x 4 columns]

# %%
# Proportion of articles containing software aliases with the software mentioned in an acknowledgement
XML_all_ack = XML_results.loc[XML_results['ack'] == 'yes']
XML_ack_proportion = XML_all_ack.groupby('Software_Package')['File_Name'].nunique()/XML_results.groupby('Software_Package')['File_Name'].nunique()
XML_ack_proportion
# Out:
# Software_Package
# AstroBlend           NaN
# Astropy         0.903346
# RADMC-3D        0.102804
# SAOImage DS9    0.486804
# Spec2d          0.138158
# Stingray             NaN
# TARDIS               NaN
# WCSTools        0.081301
# Name: File_Name, dtype: float64

# %%
# Total number of unique papers with software aliases in acknowledgements

XML_all_ack = XML_results.loc[XML_results['ack'] == "yes"]
XML_ack_count = XML_all_ack.groupby('Software_Package')['File_Name'].nunique()
XML_ack_count.to_csv("XML_ack_count_082019.csv")
XML_ack_count
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """
# Software_Package
# Astropy         486
# RADMC-3D         22
# SAOImage DS9    166
# Spec2d           42
# WCSTools         10
# Name: File_Name, dtype: int64

# %%
# Which aliases were used in the papers with aliases in acknowledgements? Write results to csv
XML_ack_aliases = pd.DataFrame({'ack_count' : XML_all_ack.groupby([ "Software_Package", "Alias", "Identifier"])['File_Name'].nunique()}).reset_index()
XML_ack_aliases.to_csv("XML_ack_aliases_082019.csv")
XML_ack_aliases
# Out:
#    Software_Package                                              Alias  \
# 0           Astropy                                            AstroPy
# 1           Astropy                                            Astropy
# 2           Astropy                              Astropy Collaboration
# 3           Astropy                                            astropy
# 4           Astropy                                        astropy.org
# 5           Astropy                doi.org/10.1051/0004-6361/201322068
# 6          RADMC-3D                                              RADMC
# 7          RADMC-3D                                           RADMC-3D
# 8          RADMC-3D                                            RADMC3D
# 9          RADMC-3D  ita.uni-heidelberg.de/dullemond/software/radmc-3d
# 10         RADMC-3D                                          radmc3dPy
# 11     SAOImage DS9                                                DS9
# 12     SAOImage DS9                                          SAO Image
# 13     SAOImage DS9                                           SAOIMAGE
# 14     SAOImage DS9                                           SAOImage
# 15     SAOImage DS9                                       SAOImage DS9
# 16     SAOImage DS9                                       SAOImage ds9
# 17     SAOImage DS9                                                ds9
# 18     SAOImage DS9                                         ds9.si.edu
# 19     SAOImage DS9                  hea&hyphen;www.harvard.edu/RD/ds9
# 20     SAOImage DS9                         hea-www.harvard.edu/RD/ds9
# 21     SAOImage DS9                                       saoimage ds9
# 22           Spec2d                                    DEIMOS pipeline
# 23           Spec2d  The analysis pipeline used to reduce the DEIMO...
# 24           Spec2d                                             spec2d
# 25         WCSTools                                           WCSTOOLS
# 26         WCSTools                                           WCSTools
# 27         WCSTools       tdc&hyphen;www.harvard.edu/software/wcstools
#
#    Identifier  ack_count
# 0           0         23
# 1           0        398
# 2           0          5
# 3           0         68
# 4           0         35
# 5           1          2
# 6           0         10
# 7           0         11
# 8           0          1
# 9           0          2
# 10          0          2
# 11          0          8
# 12          0          1
# 13          0          2
# 14          0          3
# 15          0        143
# 16          0          3
# 17          0          4
# 18          0          1
# 19          0          1
# 20          0          2
# 21          0          1
# 22          0          2
# 23          0         30
# 24          0         10
# 25          0          1
# 26          0          9
# 27          0          1

# %%
# Proportion of articles containing software aliases with the software mentioned in a footnote
XML_all_fn = XML_results.loc[XML_results['fn'] == 'yes']
XML_fn_proportion = XML_all_fn.groupby('Software_Package')['File_Name'].nunique()/XML_results.groupby('Software_Package')['File_Name'].nunique()
XML_fn_proportion
# Out:
# Software_Package
# AstroBlend      1.000000
# Astropy         0.089219
# RADMC-3D        0.252336
# SAOImage DS9    0.140762
# Spec2d          0.243421
# Stingray        0.500000
# TARDIS               NaN
# WCSTools        0.260163
# Name: File_Name, dtype: float64

# %%
# Total number of unique papers with software aliases in footnotes

XML_all_fn = XML_results.loc[XML_results['fn'] == "yes"]
XML_fn_count = XML_all_fn.groupby('Software_Package')['File_Name'].nunique()
XML_fn_count.to_csv("XML_fn_count_082019.csv")
XML_fn_count
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """
# Software_Package
# AstroBlend       1
# Astropy         48
# RADMC-3D        54
# SAOImage DS9    48
# Spec2d          74
# Stingray         1
# WCSTools        32
# Name: File_Name, dtype: int64

# %%
# Which aliases were used in the papers with aliases in footnotes? Write results to csv
XML_fn_aliases = pd.DataFrame({'fn_count' : XML_all_fn.groupby( [ "Software_Package", "Alias", "Identifier"])['File_Name'].nunique()}).reset_index()
XML_fn_aliases.to_csv("XML_fn_aliases_082019.csv")
XML_fn_aliases
# Out:
#    Software_Package                                              Alias  \
# 0        AstroBlend                                     astroblend.com
# 1           Astropy                                            Astropy
# 2           Astropy                                            astropy
# 3           Astropy                                        astropy.org
# 4           Astropy                       github.com/astropy/astroplan
# 5           Astropy                      github.com/astropy/astroquery
# 6           Astropy                    github.com/astropy/astroscrappy
# 7           Astropy                       github.com/astropy/photutils
# 8          RADMC-3D                                              RADMC
# 9          RADMC-3D                                           RADMC-3D
# 10         RADMC-3D                        dullemond/software/radmc-3d
# 11         RADMC-3D  ita.uni-heidelberg.de/dullemond/software/radmc-3d
# 12         RADMC-3D  ita.uni-heidelberg.de/~dullemond/software/radm...
# 13         RADMC-3D  ita.uni-heidelberg.de∼deullemond/software/radm...
# 14         RADMC-3D                                              radmc
# 15         RADMC-3D                                           radmc-3d
# 16     SAOImage DS9                                                DS9
# 17     SAOImage DS9                                          SAO Image
# 18     SAOImage DS9                                      SAO image ds9
# 19     SAOImage DS9                                       SAOImage DS9
# 20     SAOImage DS9                                                ds9
# 21     SAOImage DS9                                         ds9.si.edu
# 22     SAOImage DS9  hea&hyphen;www.harvard.edu/ChaMPlane/walkthrou...
# 23     SAOImage DS9                  hea&hyphen;www.harvard.edu/RD/ds9
# 24     SAOImage DS9               hea&hyphen;www.harvard.edu/RD/saotng
# 25     SAOImage DS9               hea&hyphen;www.harvard.edu/saord/ds9
# 26     SAOImage DS9                         hea-www.harvard.edu/RD/ds9
# 27     SAOImage DS9             hea-www.harvard.edu/saord/funtools/ds9
# 28           Spec2d  The analysis pipeline used to reduce the DEIMO...
# 29           Spec2d             astro.berkeley.edu/~cooper/deep/spec2d
# 30           Spec2d            astron.berkeley.edu/~cooper/deep/spec2d
# 31           Spec2d                           deep.berkeley.edu/spec2d
# 32           Spec2d                             deep.ps.uci.edu/spec2d
# 33           Spec2d                                          idlspec2d
# 34           Spec2d            juno.as.arizona.edu/~cooper/deep/spec2d
# 35           Spec2d          keck.hawaii.edu/inst/deimos/pipeline.html
# 36           Spec2d                       sdss3.org/svn/repo/idlspec2d
# 37           Spec2d                                             spec2d
# 38           Spec2d                    spectro.princeton.edu/idlspec2d
# 39         Stingray                github.com/StingraySoftware/HENDRIC
# 40         Stingray              github.com/StingraySoftware/notebooks
# 41         WCSTools                                           WCSTools
# 42         WCSTools        cfa&hyphen;ftp.harvard.edu/pub/gsc/WCSTools
# 43         WCSTools       tdc&hyphen;www.harvard.edu/software/wcstools
# 44         WCSTools          tdc-www.cfa.harvard.edu/software/wcstools
# 45         WCSTools              tdc-www.harvard.edu/software/wcstools
# 46         WCSTools                       tdc-www.harvard.edu/wcstools
# 47         WCSTools                                           wcstools
#
#    Identifier  fn_count
# 0           0         1
# 1           0         4
# 2           0         2
# 3           0        40
# 4           0         1
# 5           0         1
# 6           0         2
# 7           0         1
# 8           0         2
# 9           0         3
# 10          0         8
# 11          0         7
# 12          0        34
# 13          0         1
# 14          0         2
# 15          0         2
# 16          0         2
# 17          0         1
# 18          0         1
# 19          0         6
# 20          0         1
# 21          0        17
# 22          0         1
# 23          0         7
# 24          0         1
# 25          0         1
# 26          0        12
# 27          0         1
# 28          0         2
# 29          0        24
# 30          0         9
# 31          0         7
# 32          0         3
# 33          0         4
# 34          0         1
# 35          0         5
# 36          0         4
# 37          0         8
# 38          0        12
# 39          0         1
# 40          0         1
# 41          0         5
# 42          0         3
# 43          0         8
# 44          0         2
# 45          0         8
# 46          0        10
# 47          0         2

# %%
# Did any articles have no reference, acknowledgement, or footnote?
no_credit = XML_results.loc[(XML_results['fn'] == 'no') & (XML_results['ref'] == 'no') & (XML_results['ack'] == 'no')]
no_credit = no_credit.loc[~(no_credit['File_Name'].isin(XML_all_fn['File_Name']))]
no_credit = no_credit.loc[~(no_credit['File_Name'].isin(XML_all_refs['File_Name']))]
no_credit = no_credit.loc[~(no_credit['File_Name'].isin(XML_all_ack['File_Name']))]
no_credit.groupby('Software_Package')['File_Name'].nunique()
# Out:
# Software_Package
# Astropy          6
# RADMC-3D        20
# SAOImage DS9    94
# Spec2d          77
# Stingray         1
# WCSTools        49
# Name: File_Name, dtype: int64

# %%
# total mentions of software aliases over time
XML_over_time_journal = pd.DataFrame({'year_count' : XML_results.groupby(["Journal_Title", "Software_Package", "Pub_Year"])['File_Name'].nunique()}).reset_index()
# write results
XML_over_time_journal.to_csv("XML_over_time_journal_082019.csv")
# show results over time
XML_over_time_journal
# Out:
#                                    Journal_Title Software_Package Pub_Year  \
# 0                       The Astronomical Journal          Astropy     2014
# 1                       The Astronomical Journal          Astropy     2015
# 2                       The Astronomical Journal          Astropy     2016
# 3                       The Astronomical Journal          Astropy     2017
# 4                       The Astronomical Journal          Astropy     2018
# 5                       The Astronomical Journal         RADMC-3D     2010
# 6                       The Astronomical Journal         RADMC-3D     2016
# 7                       The Astronomical Journal         RADMC-3D     2017
# 8                       The Astronomical Journal         RADMC-3D     2018
# 9                       The Astronomical Journal     SAOImage DS9     1998
# 10                      The Astronomical Journal     SAOImage DS9     2000
# 11                      The Astronomical Journal     SAOImage DS9     2002
# 12                      The Astronomical Journal     SAOImage DS9     2004
# 13                      The Astronomical Journal     SAOImage DS9     2006
# 14                      The Astronomical Journal     SAOImage DS9     2007
# 15                      The Astronomical Journal     SAOImage DS9     2008
# 16                      The Astronomical Journal     SAOImage DS9     2009
# 17                      The Astronomical Journal     SAOImage DS9     2010
# 18                      The Astronomical Journal     SAOImage DS9     2011
# 19                      The Astronomical Journal     SAOImage DS9     2012
# 20                      The Astronomical Journal     SAOImage DS9     2013
# 21                      The Astronomical Journal     SAOImage DS9     2014
# 22                      The Astronomical Journal     SAOImage DS9     2015
# 23                      The Astronomical Journal     SAOImage DS9     2016
# 24                      The Astronomical Journal     SAOImage DS9     2017
# 25                      The Astronomical Journal     SAOImage DS9     2018
# 26                      The Astronomical Journal           Spec2d     2002
# 27                      The Astronomical Journal           Spec2d     2004
# 28                      The Astronomical Journal           Spec2d     2005
# 29                      The Astronomical Journal           Spec2d     2006
# ..                                           ...              ...      ...
# 190  The Astrophysical Journal Supplement Series     SAOImage DS9     2010
# 191  The Astrophysical Journal Supplement Series     SAOImage DS9     2011
# 192  The Astrophysical Journal Supplement Series     SAOImage DS9     2012
# 193  The Astrophysical Journal Supplement Series     SAOImage DS9     2013
# 194  The Astrophysical Journal Supplement Series     SAOImage DS9     2014
# 195  The Astrophysical Journal Supplement Series     SAOImage DS9     2015
# 196  The Astrophysical Journal Supplement Series     SAOImage DS9     2016
# 197  The Astrophysical Journal Supplement Series     SAOImage DS9     2017
# 198  The Astrophysical Journal Supplement Series     SAOImage DS9     2018
# 199  The Astrophysical Journal Supplement Series           Spec2d     2007
# 200  The Astrophysical Journal Supplement Series           Spec2d     2008
# 201  The Astrophysical Journal Supplement Series           Spec2d     2010
# 202  The Astrophysical Journal Supplement Series           Spec2d     2011
# 203  The Astrophysical Journal Supplement Series           Spec2d     2012
# 204  The Astrophysical Journal Supplement Series           Spec2d     2013
# 205  The Astrophysical Journal Supplement Series           Spec2d     2014
# 206  The Astrophysical Journal Supplement Series           Spec2d     2015
# 207  The Astrophysical Journal Supplement Series           Spec2d     2016
# 208  The Astrophysical Journal Supplement Series           Spec2d     2017
# 209  The Astrophysical Journal Supplement Series           Spec2d     2018
# 210  The Astrophysical Journal Supplement Series           TARDIS     2015
# 211  The Astrophysical Journal Supplement Series         WCSTools     2004
# 212  The Astrophysical Journal Supplement Series         WCSTools     2005
# 213  The Astrophysical Journal Supplement Series         WCSTools     2006
# 214  The Astrophysical Journal Supplement Series         WCSTools     2009
# 215  The Astrophysical Journal Supplement Series         WCSTools     2010
# 216  The Astrophysical Journal Supplement Series         WCSTools     2011
# 217  The Astrophysical Journal Supplement Series         WCSTools     2012
# 218  The Astrophysical Journal Supplement Series         WCSTools     2015
# 219  The Astrophysical Journal Supplement Series         WCSTools     2016
#
#      year_count
# 0             4
# 1             5
# 2            14
# 3            32
# 4            21
# 5             2
# 6             1
# 7             3
# 8             1
# 9             3
# 10            1
# 11            1
# 12            1
# 13            5
# 14            5
# 15            2
# 16            3
# 17           10
# 18            2
# 19            7
# 20            6
# 21            3
# 22            4
# 23            5
# 24            7
# 25            3
# 26            1
# 27            1
# 28            1
# 29            2
# ..          ...
# 190           4
# 191           9
# 192           5
# 193           9
# 194           4
# 195           6
# 196           5
# 197           2
# 198           6
# 199           1
# 200           1
# 201           2
# 202           4
# 203           1
# 204           1
# 205           4
# 206           5
# 207           4
# 208           4
# 209           2
# 210           1
# 211           3
# 212           1
# 213           1
# 214           2
# 215           1
# 216           3
# 217           1
# 218           1
# 219           1
#
# [220 rows x 4 columns]

# %%
#XML_over_time_journal = pd.DataFrame({'year_count' : XML_results.groupby(["Journal_Title", "Software_Package", "Pub_Year"])['File_Name'].nunique()}).reset_index()

XML_alias_per_paper = pd.DataFrame({'count' : XML_results.groupby('File_Name')['Alias'].count()})
# XML_alias_per_paper.to_csv("XML_alias_per_paper_082019.csv")
XML_alias_per_paper
# Out:
#                     count
# File_Name
# 10.1086_300314.xml      1
# 10.1086_300338.xml      1
# 10.1086_300462.xml      1
# 10.1086_300535.xml      1
# 10.1086_300997.xml      1
# 10.1086_301493.xml      1
# 10.1086_304882.xml      2
# 10.1086_312617.xml      1
# 10.1086_313204.xml      1
# 10.1086_318776.xml      1
# 10.1086_320409.xml      2
# 10.1086_321176.xml      1
# 10.1086_321561.xml      1
# 10.1086_324741.xml      2
# 10.1086_339572.xml      2
# 10.1086_340936.xml      2
# 10.1086_341649.xml      1
# 10.1086_342702.xml      2
# 10.1086_342738.xml      3
# 10.1086_343127.xml      1
# 10.1086_344306.xml      1
# 10.1086_346233.xml      2
# 10.1086_346277.xml      2
# 10.1086_374040.xml      1
# 10.1086_375528.xml      1
# 10.1086_376406.xml      1
# 10.1086_377620.xml      1
# 10.1086_378977.xml      1
# 10.1086_379887.xml      1
# 10.1086_380120.xml      1
# ...                   ...
# apjs_230_2_23.xml       4
# apjs_231_1_11.xml       7
# apjs_231_1_13.xml       1
# apjs_231_1_7.xml        2
# apjs_232_1_6.xml        6
# apjs_233_1_1.xml        3
# apjs_233_1_4.xml        1
# apjs_233_1_9.xml        4
# apjs_233_2_17.xml       4
# apjs_233_2_21.xml       2
# apjs_233_2_26.xml       4
# apjs_234_1_2.xml        4
# apjs_234_1_4.xml        8
# apjs_234_1_7.xml        1
# apjs_234_1_8.xml        1
# apjs_234_2_18.xml       4
# apjs_234_2_21.xml       2
# apjs_234_2_22.xml       5
# apjs_234_2_35.xml       5
# apjs_234_2_36.xml       6
# apjs_235_1_10.xml       1
# apjs_235_1_14.xml       6
# apjs_235_1_17.xml       4
# apjs_235_1_20.xml       4
# apjs_235_1_3.xml        4
# apjs_235_2_32.xml       1
# apjs_235_2_33.xml       5
# apjs_235_2_36.xml       1
# apjs_235_2_42.xml       1
# apjs_235_2_43.xml       4
#
# [1469 rows x 1 columns]

# %%
#Alias per paper

XML_papers_over_time = pd.DataFrame(XML_results.groupby(['Software_Package','Pub_Year'])['File_Name'].nunique())
XML_papers_over_time.to_csv("XML_papers_over_time_082019.csv")
XML_papers_over_time
# Out:
#                            File_Name
# Software_Package Pub_Year
# AstroBlend       2016              1
# Astropy          2012              1
#                  2013              3
#                  2014             37
#                  2015             63
#                  2016            117
#                  2017            199
#                  2018            118
# RADMC-3D         2004              1
#                  2005              1
#                  2006              1
#                  2007              4
#                  2008              4
#                  2009             14
#                  2010             19
#                  2011             13
#                  2012             23
#                  2013             15
#                  2014             13
#                  2015             28
#                  2016             29
#                  2017             37
#                  2018             12
# SAOImage DS9     1997              1
#                  1998              3
#                  1999              1
#                  2000              2
#                  2001              1
#                  2002              2
#                  2003              2
# ...                              ...
# Spec2d           2013             24
#                  2014             29
#                  2015             39
#                  2016             41
#                  2017             30
#                  2018             11
# Stingray         2018              2
# TARDIS           2015              1
#                  2016              2
#                  2017              1
# WCSTools         1998              1
#                  1999              1
#                  2001              3
#                  2002              5
#                  2003              3
#                  2004              6
#                  2005              6
#                  2006              6
#                  2007              9
#                  2008              4
#                  2009              7
#                  2010             18
#                  2011             12
#                  2012             14
#                  2013              9
#                  2014              3
#                  2015              6
#                  2016              3
#                  2017              6
#                  2018              1
#
# [86 rows x 1 columns]

# %%
XML_alias_per_paper = pd.DataFrame({'count' : XML_results.groupby(["Software_Package","File_Name"])['Alias'].nunique()})
XML_alias_per_paper.to_csv("XML_alias_per_paper_082019.csv")
XML_alias_per_paper
# Out:
#                                      count
# Software_Package File_Name
# AstroBlend       apj_818_2_115.xml       2
# Astropy          aj_148_1_13.xml         4
#                  aj_148_1_14.xml         5
#                  aj_148_3_53.xml         4
#                  aj_148_6_122.xml        4
#                  aj_150_4_118.xml        4
#                  aj_150_4_132.xml        4
#                  aj_150_5_145.xml        4
#                  aj_150_6_179.xml        4
#                  aj_150_6_189.xml        4
#                  aj_151_1_3.xml          1
#                  aj_151_2_41.xml         4
#                  aj_151_3_61.xml         4
#                  aj_151_4_99.xml         4
#                  aj_151_6_158.xml        1
#                  aj_151_6_173.xml        3
#                  aj_152_1_9.xml          1
#                  aj_152_2_40.xml         4
#                  aj_152_3_70.xml         4
#                  aj_152_5_123.xml        4
#                  aj_152_6_154.xml        4
#                  aj_152_6_178.xml        2
#                  aj_152_6_212.xml        1
#                  aj_152_6_228.xml        7
#                  aj_153_1_10.xml         4
#                  aj_153_1_13.xml         4
#                  aj_153_1_3.xml          3
#                  aj_153_2_58.xml         1
#                  aj_153_3_107.xml        6
#                  aj_153_3_116.xml        4
# ...                                    ...
# WCSTools         apj_763_2_96.xml        1
#                  apj_767_1_62.xml        1
#                  apj_770_2_107.xml       2
#                  apj_772_2_126.xml       1
#                  apj_778_1_19.xml        1
#                  apj_778_2_91.xml        2
#                  apj_779_1_42.xml        3
#                  apj_787_1_55.xml        2
#                  apj_789_2_138.xml       1
#                  apj_809_1_17.xml        1
#                  apj_815_2_120.xml       1
#                  apj_818_1_67.xml        2
#                  apj_825_2_151.xml       2
#                  apj_837_1_62.xml        2
#                  apj_846_1_67.xml        1
#                  apj_850_2_155.xml       2
#                  apj_856_2_109.xml       2
#                  apjl_746_1_11.xml       1
#                  apjl_749_1_2.xml        2
#                  apjl_765_1_19.xml       2
#                  apjl_807_1_L2.xml       2
#                  apjs_184_1_172.xml      1
#                  apjs_185_1_85.xml       1
#                  apjs_188_1_75.xml       2
#                  apjs_193_1_12.xml       2
#                  apjs_193_2_26.xml       3
#                  apjs_193_2_28.xml       2
#                  apjs_203_1_2.xml        2
#                  apjs_218_2_29.xml       1
#                  apjs_225_1_11.xml       2
#
# [1527 rows x 1 columns]
