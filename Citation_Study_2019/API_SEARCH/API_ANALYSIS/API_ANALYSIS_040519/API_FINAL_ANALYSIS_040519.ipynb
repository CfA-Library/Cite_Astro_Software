# %% [markdown]
# # API Final Analysis
# ### Daina Bouquin, Daniel Chivvis
#
# Scripts below were used to generate all .csv files in the API_RESULTS_040519/ folder

# %%
import pandas as pd
import numpy as np

# %%
API_results = pd.read_csv("API_CLEAN_INPUT_040519.csv")

# %%
list(API_results.columns.values)
# Out:
# ['Alias',
#  'Software_Package',
#  'Identifier',
#  'Highlight',
#  'Citation',
#  'Bibcode',
#  'Alternate_Bibcode',
#  'BibGroup',
#  'Publisher',
#  'Article_ID',
#  'DOI',
#  'Pub_Year',
#  'Author',
#  'Title']

# %%
API_results.head(5)
# Out:
#         Alias Software_Package  Identifier  \
# 0  AstroBlend       AstroBlend           0
# 1  AstroBlend       AstroBlend           0
# 2  AstroBlend       AstroBlend           0
# 3  AstroBlend       AstroBlend           0
# 4  AstroBlend       AstroBlend           0
#
#                                            Highlight Citation  \
# 0  of this article.)Fig.9Isocontours generated wi...    False
# 1  From that perspective, recent efforts like fre...     True
# 2  -passing the X3D file format altogether), we r...    False
# 3  AstroBlend6 6 <em>www.astroblend.com&#x2F;</em...     True
# 4  on Big Data from Space (BiDS 2014)2014232235Na...     True
#
#                Bibcode    Alternate_Bibcode BibGroup  \
# 0  2016A&C....15...50N  2016arXiv160203178N      CfA
# 1  2017PASP..129e8012V  2016arXiv161103862V      NaN
# 2  2016ApJ...818..115V  2015arXiv151002796V      NaN
# 3  2017PASP..129e8010G  2016arXiv161106965G      NaN
# 4  2017A&C....19...45P  2017arXiv170306651P      NaN
#
#                                            Publisher  \
# 0                            Astronomy and Computing
# 1  Publications of the Astronomical Society of th...
# 2                          The Astrophysical Journal
# 3  Publications of the Astronomical Society of th...
# 4                            Astronomy and Computing
#
#                                           Article_ID  \
# 0  2016arXiv160203178N|2016A&C....15...50N|10.101...
# 1  2016arXiv161103862V|2017PASP..129e8012V|10.108...
# 2  2015arXiv151002796V|2016ApJ...818..115V|10.384...
# 3  2016arXiv161106965G|2017PASP..129e8010G|10.108...
# 4  2017arXiv170306651P|2017A&C....19...45P|10.101...
#
#                                 DOI  Pub_Year                Author  \
# 0       10.1016/j.ascom.2016.02.002      2016         Naiman, J. P.
# 1  10.1088/1538-3873/129/975/058012      2017  Vogt, Fr�d�ric P. A.
# 2       10.3847/0004-637X/818/2/115      2016  Vogt, Fr�d�ric P. A.
# 3  10.1088/1538-3873/129/975/058010      2017        G�rate, Mat�as
# 4       10.1016/j.ascom.2017.03.004      2017             Punzo, D.
#
#                                                Title
# 0  AstroBlend: An astrophysical visualization pac...
# 1  Linking the X3D Pathway to Integral Field Spec...
# 2  Advanced Data Visualization in Astrophysics: T...
# 3    Voxel Datacubes for 3D Visualization in Blender
# 4  SlicerAstro: A 3-D interactive visual analytic...

# %%
# Convert highlight col to string

API_results['Highlight'] = API_results['Highlight'].astype('|S')\

# %%
API_results.to_csv("API_FINAL_ANALYSIS_040519.csv")

# %% [markdown]
# ## Summary of Results

# %%
# How many papers did we find for each software package?
API_results.groupby('Software_Package')['Bibcode'].nunique()
# Out:
# Software_Package
# AstroBlend         5
# AstroPy          781
# PlasmaPy           2
# RADMC-3D         455
# SAOImage DS9    1135
# Spec2d           248
# Stingray           6
# TARDIS            28
# WCS Tools        326
# Name: Bibcode, dtype: int64

# %%
# Proportion of articles with a software alias in a citation
API_all_citations = API_results.loc[API_results['Citation'] == True]
API_cite_proportion = API_all_citations.groupby('Software_Package')['Bibcode'].nunique()/API_results.groupby('Software_Package')['Bibcode'].nunique()
API_cite_proportion
# Out:
# Software_Package
# AstroBlend      0.600000
# AstroPy         0.742638
# PlasmaPy        1.000000
# RADMC-3D        0.742857
# SAOImage DS9    0.437885
# Spec2d          0.516129
# Stingray        0.500000
# TARDIS          0.892857
# WCS Tools       0.582822
# Name: Bibcode, dtype: float64

# %%
# How many unique aliases were used in citations for each package?
print (API_all_citations.groupby('Software_Package')['Alias'].nunique())
# Out:
# Software_Package
# AstroBlend       2
# AstroPy          7
# PlasmaPy         1
# RADMC-3D        11
# SAOImage DS9     9
# Spec2d           8
# Stingray         2
# TARDIS           3
# WCS Tools       10
# Name: Alias, dtype: int64

# %%
# Which aliases were used in the papers with aliases in references? Write results to csv
API_cite_aliases = pd.DataFrame({'cite_count' : API_all_citations.groupby(['Software_Package', 'Alias', 'Identifier'])['Bibcode'].nunique()}).reset_index()
API_cite_aliases.to_csv("API_cite_aliases_040519.csv")
API_cite_aliases
# Out:
#    Software_Package                                              Alias  \
# 0        AstroBlend                                         AstroBlend
# 1        AstroBlend                                     astroblend.com
# 2           AstroPy                        10.1051/0004-6361/201322068
# 3           AstroPy                                            AstroPy
# 4           AstroPy                Astropy Collaboration et al. (2018)
# 5           AstroPy                                    arXiv:1307.6212
# 6           AstroPy                                   arXiv:1801.02634
# 7           AstroPy                                        astropy.org
# 8           AstroPy                                 github.com/astropy
# 9          PlasmaPy                                           PlasmaPy
# 10         RADMC-3D                         10.1051/0004-6361:20031768
# 11         RADMC-3D                         10.1051/0004-6361:20040017
# 12         RADMC-3D                                           RADMC-2D
# 13         RADMC-3D                                           RADMC-3D
# 14         RADMC-3D                                            RADMC3D
# 15         RADMC-3D                                      ascl:1108.016
# 16         RADMC-3D                                      ascl:1202.015
# 17         RADMC-3D  ita.uni-heidelberg.de/~dullemond/software/radm...
# 18         RADMC-3D                                              radmc
# 19         RADMC-3D                                            radmc2d
# 20         RADMC-3D                                            radmc3d
# 21     SAOImage DS9                                               DS9
# 22     SAOImage DS9                                               ds9
# 23     SAOImage DS9                                           SAOImage
# 24     SAOImage DS9                                       SAOImage DS9
# 25     SAOImage DS9                                             SAOtng
# 26     SAOImage DS9  This work was performed in large part under a ...
# 27     SAOImage DS9                                      ascl:0003.002
# 28     SAOImage DS9                                         ds9.si.edu
# 29     SAOImage DS9                                              pyds9
# 30           Spec2d                         DEEP2 DEIMOS data pipeline
# 31           Spec2d                              DEEP2 DEIMOS pipeline
# 32           Spec2d                                    DEIMOS pipeline
# 33           Spec2d                                             Spec2d
# 34           Spec2d  The analysis pipeline used to reduce the DEIMO...
# 35           Spec2d                                    arXiv:1203.3192
# 36           Spec2d                                      ascl:1203.003
# 37           Spec2d                             deep.ps.uci.edu/spec2d
# 38         Stingray                                           Stingray
# 39         Stingray               github.com/StingraySoftware/stingray
# 40           TARDIS                                             TARDIS
# 41           TARDIS                                             Tardis
# 42           TARDIS                              tardis.readthedocs.io
# 43        WCS Tools                                             LibWCS
# 44        WCS Tools                                          WCS Tools
# 45        WCS Tools                                             WCSLIB
# 46        WCS Tools                                           WCSTools
# 47        WCS Tools                                            gethead
# 48        WCS Tools                                              imwcs
# 49        WCS Tools                                            sethead
# 50        WCS Tools                                             sky2xy
# 51        WCS Tools              tdc-www.harvard.edu/software/wcstools
# 52        WCS Tools                                             xy2sky
#
#     Identifier  cite_count
# 0            0           3
# 1            0           1
# 2            1           3
# 3            0         576
# 4            0          64
# 5            1           6
# 6            1          12
# 7            0          41
# 8            0           7
# 9            0           2
# 10           1           1
# 11           1           1
# 12           0           5
# 13           0         131
# 14           0         130
# 15           1           1
# 16           1           3
# 17           0          14
# 18           0         309
# 19           0           2
# 20           0          58
# 21           0         268
# 22           0         218
# 23           0         160
# 24           0          90
# 25           0          10
# 26           0           1
# 27           1           1
# 28           0          29
# 29           0           1
# 30           0           1
# 31           0           7
# 32           0          10
# 33           0         107
# 34           0           2
# 35           1          12
# 36           1           1
# 37           0           1
# 38           0           3
# 39           0           1
# 40           0          13
# 41           0          13
# 42           0           1
# 43           0           1
# 44           0           6
# 45           0          14
# 46           0         144
# 47           0          12
# 48           0          26
# 49           0           3
# 50           0           5
# 51           0           7
# 52           0          10

# %%
# proportion of identifiers among software aliases in citations 
API_identifier_prop = API_results.loc[API_results['Identifier'] == 1]
API_identifier_prop = API_identifier_prop.groupby('Software_Package')['Bibcode'].nunique()/API_results.groupby('Software_Package')['Bibcode'].nunique()
API_identifier_prop
# Out:
# Software_Package
# AstroBlend           NaN
# AstroPy         0.089629
# PlasmaPy        0.500000
# RADMC-3D        0.028571
# SAOImage DS9    0.006167
# Spec2d          0.084677
# Stingray             NaN
# TARDIS               NaN
# WCS Tools            NaN
# Name: Bibcode, dtype: float64

# %%
# total mentions of software aliases over time
API_over_time = pd.DataFrame({'year_count' : API_results.groupby(["Software_Package", "Pub_Year"])['Bibcode'].nunique()}).reset_index()
# write results
API_over_time.to_csv("API_over_time_040519.csv")
# show results over time
API_over_time
# Out:
#     Software_Package  Pub_Year  year_count
# 0         AstroBlend      2016           2
# 1         AstroBlend      2017           3
# 2            AstroPy      1997           1
# 3            AstroPy      2000           2
# 4            AstroPy      2007           1
# 5            AstroPy      2008           1
# 6            AstroPy      2013           9
# 7            AstroPy      2014          29
# 8            AstroPy      2015          55
# 9            AstroPy      2016         112
# 10           AstroPy      2017         150
# 11           AstroPy      2018         382
# 12           AstroPy      2019          39
# 13          PlasmaPy      2018           2
# 14          RADMC-3D      2004           5
# 15          RADMC-3D      2005           5
# 16          RADMC-3D      2006           6
# 17          RADMC-3D      2007          13
# 18          RADMC-3D      2008           9
# 19          RADMC-3D      2009          16
# 20          RADMC-3D      2010          19
# 21          RADMC-3D      2011          20
# 22          RADMC-3D      2012          29
# 23          RADMC-3D      2013          31
# 24          RADMC-3D      2014          38
# 25          RADMC-3D      2015          47
# 26          RADMC-3D      2016          68
# 27          RADMC-3D      2017          65
# 28          RADMC-3D      2018          80
# 29          RADMC-3D      2019           4
# ..               ...       ...         ...
# 71          Stingray      2019           2
# 72            TARDIS      2014           1
# 73            TARDIS      2015           4
# 74            TARDIS      2016           8
# 75            TARDIS      2017           6
# 76            TARDIS      2018           7
# 77            TARDIS      2019           2
# 78         WCS Tools      1997           4
# 79         WCS Tools      1998           1
# 80         WCS Tools      1999           5
# 81         WCS Tools      2000           2
# 82         WCS Tools      2001           8
# 83         WCS Tools      2002          12
# 84         WCS Tools      2003          10
# 85         WCS Tools      2004          13
# 86         WCS Tools      2005          11
# 87         WCS Tools      2006          12
# 88         WCS Tools      2007          20
# 89         WCS Tools      2008          16
# 90         WCS Tools      2009          21
# 91         WCS Tools      2010          29
# 92         WCS Tools      2011          29
# 93         WCS Tools      2012          25
# 94         WCS Tools      2013          21
# 95         WCS Tools      2014          15
# 96         WCS Tools      2015          19
# 97         WCS Tools      2016          16
# 98         WCS Tools      2017          16
# 99         WCS Tools      2018          20
# 100        WCS Tools      2019           1
#
# [101 rows x 3 columns]
