# %% [markdown]
# # API Final Analysis
# ### Daina Bouquin, Daniel Chivvis
#
# Scripts below were used to generate all .csv files in the API_RESULTS/ folder

# %%
import pandas as pd
import numpy as np

# %%
API_results = pd.read_csv("API_CLEAN_INPUT_050719.csv")

# %%
list(API_results.columns.values)
# Out:
# ['Alias',
#  'Software_Package',
#  'Identifier',
#  'Highlight',
#  'Citation',
#  'Bibcode',
#  'Alternate Bibcode',
#  'BibGroup',
#  'Publisher',
#  'Article_ID',
#  'DOI',
#  'Pub_Year',
#  'Author',
#  'Title']

# %%
API_results.head(5)
# Out:
#             Alias Software_Package  Identifier  \
# 0      AstroBlend       AstroBlend           0
# 1      AstroBlend       AstroBlend           0
# 2  astroblend.com       AstroBlend           0
# 3  astroblend.com       AstroBlend           0
# 4      AstroBlend       AstroBlend           0
#
#                                            Highlight  Citation  \
# 0  of this article.)Fig.9Isocontours generated wi...     False
# 1  -passing the X3D file format altogether), we r...     False
# 2  #x2014; www.<em>astroblend.com</em> #x2014; ha...     False
# 3  -passing the X3D file format altogether), we r...     False
# 4  From that perspective, recent efforts like fre...      True
#
#                Bibcode    Alternate Bibcode BibGroup  \
# 0  2016A&C....15...50N  2016arXiv160203178N      CfA
# 1  2016ApJ...818..115V  2015arXiv151002796V      NaN
# 2  2016A&C....15...50N  2016arXiv160203178N      CfA
# 3  2016ApJ...818..115V  2015arXiv151002796V      NaN
# 4  2017PASP..129e8012V  2016arXiv161103862V      NaN
#
#                                            Publisher  \
# 0                            Astronomy and Computing
# 1                          The Astrophysical Journal
# 2                            Astronomy and Computing
# 3                          The Astrophysical Journal
# 4  Publications of the Astronomical Society of th...
#
#                                           Article_ID  \
# 0  2016arXiv160203178N|2016A&C....15...50N|10.101...
# 1  2015arXiv151002796V|2016ApJ...818..115V|10.384...
# 2  2016arXiv160203178N|2016A&C....15...50N|10.101...
# 3  2015arXiv151002796V|2016ApJ...818..115V|10.384...
# 4  2016arXiv161103862V|2017PASP..129e8012V|10.108...
#
#                                 DOI  Pub_Year                Author  \
# 0       10.1016/j.ascom.2016.02.002      2016         Naiman, J. P.
# 1       10.3847/0004-637X/818/2/115      2016  Vogt, Frédéric P. A.
# 2       10.1016/j.ascom.2016.02.002      2016         Naiman, J. P.
# 3       10.3847/0004-637X/818/2/115      2016  Vogt, Frédéric P. A.
# 4  10.1088/1538-3873/129/975/058012      2017  Vogt, Frédéric P. A.
#
#                                                Title
# 0  AstroBlend: An astrophysical visualization pac...
# 1  Advanced Data Visualization in Astrophysics: T...
# 2  AstroBlend: An astrophysical visualization pac...
# 3  Advanced Data Visualization in Astrophysics: T...
# 4  Linking the X3D Pathway to Integral Field Spec...

# %%
# Convert highlight col to string

API_results['Highlight'] = API_results['Highlight'].astype('|S')\

# %%
API_results.to_csv("API_FINAL_ANALYSIS_050719.csv")

# %% [markdown]
# ## Summary of Results

# %%
# How many papers did we find for each software package?
API_results.groupby('Software_Package')['Bibcode'].nunique()
# Out:
# Software_Package
# AstroBlend         5
# AstroPy          450
# RADMC-3D         400
# SAOImage DS9    1055
# Spec2d           232
# Stingray          27
# TARDIS            91
# WCS Tools        309
# Name: Bibcode, dtype: int64

# %%
# Proportion of articles with a software alias in a citation
API_all_citations = API_results.loc[API_results['Citation'] == True]
API_cite_proportion = API_all_citations.groupby('Software_Package')['Bibcode'].nunique()/API_results.groupby('Software_Package')['Bibcode'].nunique()
API_cite_proportion
# Out:
# Software_Package
# AstroBlend      0.600000
# AstroPy         0.706667
# RADMC-3D        0.740000
# SAOImage DS9    0.434123
# Spec2d          0.512931
# Stingray        0.518519
# TARDIS          0.615385
# WCS Tools       0.585761
# Name: Bibcode, dtype: float64

# %%
# How many unique aliases were used in citations for each package?
print (API_all_citations.groupby('Software_Package')['Alias'].nunique())
# Out:
# Software_Package
# AstroBlend       2
# AstroPy          7
# RADMC-3D        11
# SAOImage DS9     9
# Spec2d           8
# Stingray         1
# TARDIS           2
# WCS Tools       10
# Name: Alias, dtype: int64

# %%
# Which aliases were used in the papers with aliases in references? Write results to csv
API_cite_aliases = pd.DataFrame({'cite_count' : API_all_citations.groupby(['Software_Package', 'Alias', 'Identifier'])['Bibcode'].nunique()}).reset_index()
API_cite_aliases.to_csv("API_cite_aliases_050719.csv")
API_cite_aliases
# Out:
#    Software_Package                                              Alias  \
# 0        AstroBlend                                         AstroBlend
# 1        AstroBlend                                     astroblend.com
# 2           AstroPy                        10.1051/0004-6361/201322068
# 3           AstroPy                                            AstroPy
# 4           AstroPy                Astropy Collaboration et al. (2018)
# 5           AstroPy                                    arXiv:1307.6212
# 6           AstroPy                                   arXiv:1801.02634
# 7           AstroPy                                        astropy.org
# 8           AstroPy                                 github.com/astropy
# 9          RADMC-3D                         10.1051/0004-6361:20031768
# 10         RADMC-3D                         10.1051/0004-6361:20040017
# 11         RADMC-3D                                           RADMC-2D
# 12         RADMC-3D                                           RADMC-3D
# 13         RADMC-3D                                            RADMC3D
# 14         RADMC-3D                                      ascl:1108.016
# 15         RADMC-3D                                      ascl:1202.015
# 16         RADMC-3D  ita.uni-heidelberg.de/~dullemond/software/radm...
# 17         RADMC-3D                                              radmc
# 18         RADMC-3D                                            radmc2d
# 19         RADMC-3D                                            radmc3d
# 20     SAOImage DS9                                                DS9
# 21     SAOImage DS9                                           SAOImage
# 22     SAOImage DS9                                       SAOImage DS9
# 23     SAOImage DS9                                             SAOtng
# 24     SAOImage DS9  This work was performed in large part under a ...
# 25     SAOImage DS9                                      ascl:0003.002
# 26     SAOImage DS9                                                ds9
# 27     SAOImage DS9                                         ds9.si.edu
# 28     SAOImage DS9                                              pyds9
# 29           Spec2d                         DEEP2 DEIMOS data pipeline
# 30           Spec2d                              DEEP2 DEIMOS pipeline
# 31           Spec2d                                    DEIMOS pipeline
# 32           Spec2d                                             Spec2d
# 33           Spec2d  The analysis pipeline used to reduce the DEIMO...
# 34           Spec2d                                    arXiv:1203.3192
# 35           Spec2d                                      ascl:1203.003
# 36           Spec2d                             deep.ps.uci.edu/spec2d
# 37         Stingray                                           Stingray
# 38           TARDIS                                             TARDIS
# 39           TARDIS                                             Tardis
# 40        WCS Tools                                             LibWCS
# 41        WCS Tools                                          WCS Tools
# 42        WCS Tools                                             WCSLIB
# 43        WCS Tools                                           WCSTools
# 44        WCS Tools                                            gethead
# 45        WCS Tools                                              imwcs
# 46        WCS Tools                                            sethead
# 47        WCS Tools                                             sky2xy
# 48        WCS Tools              tdc-www.harvard.edu/software/wcstools
# 49        WCS Tools                                             xy2sky
#
#     Identifier  cite_count
# 0            0           3
# 1            0           1
# 2            1           1
# 3            0         317
# 4            0           7
# 5            1           3
# 6            1           2
# 7            0          27
# 8            0           6
# 9            1           1
# 10           1           1
# 11           0           3
# 12           0         103
# 13           0         103
# 14           1           1
# 15           1           2
# 16           0          13
# 17           0         274
# 18           0           1
# 19           0          51
# 20           0         247
# 21           0         150
# 22           0          84
# 23           0          10
# 24           0           1
# 25           1           1
# 26           0         198
# 27           0          22
# 28           0           1
# 29           0           1
# 30           0           7
# 31           0          10
# 32           0          98
# 33           0           2
# 34           1          12
# 35           1           1
# 36           0           1
# 37           0          14
# 38           0          27
# 39           0          29
# 40           0           1
# 41           0           6
# 42           0          13
# 43           0         136
# 44           0          12
# 45           0          26
# 46           0           3
# 47           0           5
# 48           0           7
# 49           0           9

# %%
# proportion of identifiers among software aliases in citations 
API_identifier_prop = API_results.loc[API_results['Identifier'] == 1]
API_identifier_prop = API_identifier_prop.groupby('Software_Package')['Bibcode'].nunique()/API_results.groupby('Software_Package')['Bibcode'].nunique()
API_identifier_prop
# Out:
# Software_Package
# AstroBlend           NaN
# AstroPy         0.042222
# RADMC-3D        0.025000
# SAOImage DS9    0.005687
# Spec2d          0.081897
# Stingray             NaN
# TARDIS               NaN
# WCS Tools            NaN
# Name: Bibcode, dtype: float64

# %%
# total mentions of software aliases over time
API_over_time = pd.DataFrame({'year_count' : API_results.groupby(["Software_Package", "Pub_Year"])['Bibcode'].nunique()}).reset_index()
# write results
API_over_time.to_csv("API_over_time_050719.csv")
# show results over time
API_over_time
# Out:
#     Software_Package  Pub_Year  year_count
# 0         AstroBlend      2016           2
# 1         AstroBlend      2017           3
# 2            AstroPy      1997           1
# 3            AstroPy      2000           2
# 4            AstroPy      2007           1
# 5            AstroPy      2008           1
# 6            AstroPy      2013           9
# 7            AstroPy      2014          29
# 8            AstroPy      2015          55
# 9            AstroPy      2016         112
# 10           AstroPy      2017         150
# 11           AstroPy      2018          90
# 12          RADMC-3D      2004           5
# 13          RADMC-3D      2005           5
# 14          RADMC-3D      2006           6
# 15          RADMC-3D      2007          13
# 16          RADMC-3D      2008           9
# 17          RADMC-3D      2009          16
# 18          RADMC-3D      2010          19
# 19          RADMC-3D      2011          20
# 20          RADMC-3D      2012          29
# 21          RADMC-3D      2013          31
# 22          RADMC-3D      2014          38
# 23          RADMC-3D      2015          47
# 24          RADMC-3D      2016          68
# 25          RADMC-3D      2017          65
# 26          RADMC-3D      2018          29
# 27      SAOImage DS9      1997          23
# 28      SAOImage DS9      1998          15
# 29      SAOImage DS9      1999          10
# ..               ...       ...         ...
# 74            TARDIS      2011           1
# 75            TARDIS      2012           4
# 76            TARDIS      2013           6
# 77            TARDIS      2014          15
# 78            TARDIS      2015          15
# 79            TARDIS      2016          21
# 80            TARDIS      2017          26
# 81            TARDIS      2018           1
# 82         WCS Tools      1997           4
# 83         WCS Tools      1998           1
# 84         WCS Tools      1999           5
# 85         WCS Tools      2000           2
# 86         WCS Tools      2001           8
# 87         WCS Tools      2002          12
# 88         WCS Tools      2003          10
# 89         WCS Tools      2004          13
# 90         WCS Tools      2005          11
# 91         WCS Tools      2006          12
# 92         WCS Tools      2007          20
# 93         WCS Tools      2008          16
# 94         WCS Tools      2009          21
# 95         WCS Tools      2010          29
# 96         WCS Tools      2011          29
# 97         WCS Tools      2012          25
# 98         WCS Tools      2013          21
# 99         WCS Tools      2014          15
# 100        WCS Tools      2015          19
# 101        WCS Tools      2016          16
# 102        WCS Tools      2017          16
# 103        WCS Tools      2018           4
#
# [104 rows x 3 columns]
