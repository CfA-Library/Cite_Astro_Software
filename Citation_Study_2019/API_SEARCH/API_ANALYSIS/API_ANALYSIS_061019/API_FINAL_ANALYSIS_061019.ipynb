# %% [markdown]
# # API Final Analysis
# ### Daina Bouquin, Daniel Chivvis
#
# Scripts below were used to generate all .csv files in the API_RESULTS_061019/ folder

# %%
import pandas as pd
import numpy as np

# %%
API_results = pd.read_csv("API_CLEAN_INPUT_061019.csv")

# %%
list(API_results.columns.values)
# Out:
# ['Alias',
#  'Software_Package',
#  'Identifier',
#  'Highlight',
#  'Citation',
#  'Bibcode',
#  'Alternate_Bibcode',
#  'BibGroup',
#  'Publisher',
#  'Article_ID',
#  'DOI',
#  'Pub_Year',
#  'Pub_Date',
#  'Author',
#  'Title']

# %%
API_results.head(5)
# Out:
#             Alias Software_Package  Identifier  \
# 0  astroblend.com       Astroblend           0
# 1  astroblend.com       Astroblend           0
# 2  astroblend.com       Astroblend           0
# 3      AstroBlend       Astroblend           0
# 4      AstroBlend       Astroblend           0
#
#                                            Highlight  Citation  \
# 0  #x2014; www.<em>astroblend.com</em> #x2014; ha...     False
# 1  AstroBlend6 6 <em>www.astroblend.com&#x2F;</em...      True
# 2  -passing the X3D file format altogether), we r...     False
# 3  of this article.)Fig.9Isocontours generated wi...     False
# 4  From that perspective, recent efforts like fre...      True
#
#                Bibcode    Alternate_Bibcode BibGroup  \
# 0  2016A&C....15...50N  2016arXiv160203178N      CfA
# 1  2017PASP..129e8010G  2016arXiv161106965G      NaN
# 2  2016ApJ...818..115V  2015arXiv151002796V      NaN
# 3  2016A&C....15...50N  2016arXiv160203178N      CfA
# 4  2017PASP..129e8012V  2016arXiv161103862V      NaN
#
#                                            Publisher  \
# 0                            Astronomy and Computing
# 1  Publications of the Astronomical Society of th...
# 2                          The Astrophysical Journal
# 3                            Astronomy and Computing
# 4  Publications of the Astronomical Society of th...
#
#                                           Article_ID  \
# 0  2016arXiv160203178N|2016A&C....15...50N|10.101...
# 1  2016arXiv161106965G|2017PASP..129e8010G|10.108...
# 2  2015arXiv151002796V|2016ApJ...818..115V|10.384...
# 3  2016arXiv160203178N|2016A&C....15...50N|10.101...
# 4  2016arXiv161103862V|2017PASP..129e8012V|10.108...
#
#                                 DOI  Pub_Year    Pub_Date  \
# 0       10.1016/j.ascom.2016.02.002      2016  2016-04-00
# 1  10.1088/1538-3873/129/975/058010      2017  2017-05-00
# 2       10.3847/0004-637X/818/2/115      2016  2016-02-00
# 3       10.1016/j.ascom.2016.02.002      2016  2016-04-00
# 4  10.1088/1538-3873/129/975/058012      2017  2017-05-00
#
#                  Author                                              Title
# 0         Naiman, J. P.  AstroBlend: An astrophysical visualization pac...
# 1        Gárate, Matías    Voxel Datacubes for 3D Visualization in Blender
# 2  Vogt, Frédéric P. A.  Advanced Data Visualization in Astrophysics: T...
# 3         Naiman, J. P.  AstroBlend: An astrophysical visualization pac...
# 4  Vogt, Frédéric P. A.  Linking the X3D Pathway to Integral Field Spec...

# %%
# Convert highlight col to string

API_results['Highlight'] = API_results['Highlight'].astype('|S')\

# %%
API_results.to_csv("API_FINAL_ANALYSIS_061019.csv")

# %% [markdown]
# ## Summary of Results

# %%
# How many papers did we find for each software package?
API_results.groupby('Software_Package')['Bibcode'].nunique()
# Out:
# Software_Package
# Astroblend         5
# Astropy          437
# RADMC-3D         404
# SAOImage DS9    1080
# Spec2d           328
# Stringray        319
# TARDIS           116
# WCSTools         334
# Name: Bibcode, dtype: int64

# %%
# Proportion of articles with a software alias in a citation
API_all_citations = API_results.loc[API_results['Citation'] == True]
API_cite_proportion = API_all_citations.groupby('Software_Package')['Bibcode'].nunique()/API_results.groupby('Software_Package')['Bibcode'].nunique()
API_cite_proportion
# Out:
# Software_Package
# Astroblend      0.600000
# Astropy         0.718535
# RADMC-3D        0.742574
# SAOImage DS9    0.435185
# Spec2d          0.545732
# Stringray       0.576803
# TARDIS          0.543103
# WCSTools        0.574850
# Name: Bibcode, dtype: float64

# %%
# How many unique aliases were used in citations for each package?
print (API_all_citations.groupby('Software_Package')['Alias'].nunique())
# Out:
# Software_Package
# Astroblend       2
# Astropy         24
# RADMC-3D        15
# SAOImage DS9    17
# Spec2d          13
# Stringray        2
# TARDIS           3
# WCSTools        13
# Name: Alias, dtype: int64

# %%
# Which aliases were used in the papers with aliases in references? Write results to csv
API_cite_aliases = pd.DataFrame({'cite_count' : API_all_citations.groupby(['Software_Package', 'Alias', 'Identifier'])['Bibcode'].nunique()}).reset_index()
API_cite_aliases.to_csv("API_cite_aliases_061019.csv")
API_cite_aliases
# Out:
#    Software_Package                                              Alias  \
# 0        Astroblend                                         AstroBlend
# 1        Astroblend                                     astroblend.com
# 2           Astropy                        10.1051/0004-6361/201322068
# 3           Astropy                                            AstroPy
# 4           Astropy                              Astropy Collaboration
# 5           Astropy                         Astropy Collaboration 2013
# 6           Astropy                         Astropy Collaboration 2018
# 7           Astropy                Astropy Collaboration et al. (2013)
# 8           Astropy                Astropy Collaboration et al. (2018)
# 9           Astropy                  Astropy Collaboration et al. 2013
# 10          Astropy                  Astropy Collaboration et al. 2018
# 11          Astropy                        Astropy Collaboration, 2013
# 12          Astropy                        Astropy Collaboration, 2018
# 13          Astropy                                    arXiv:1307.6212
# 14          Astropy                                   arXiv:1801.02634
# 15          Astropy                                      ascl:1304.002
# 16          Astropy                                  astropy.cosmology
# 17          Astropy                                        astropy.org
# 18          Astropy                                      astropy.units
# 19          Astropy                                  astropy/astroplan
# 20          Astropy                                 astropy/astroquery
# 21          Astropy                               astropy/astroscrappy
# 22          Astropy                                  astropy/photutils
# 23          Astropy                                 github.com/astropy
# 24          Astropy                      github.com/astropy/astroquery
# 25          Astropy                    github.com/astropy/astroscrappy
# 26         RADMC-3D                         10.1051/0004-6361:20031768
# 27         RADMC-3D                         10.1051/0004-6361:20040017
# 28         RADMC-3D                                              RADMC
# 29         RADMC-3D                                           RADMC-2D
# ..              ...                                                ...
# 59           Spec2d               DEEP2 DEIMOS Data Reduction Pipeline
# 60           Spec2d                              DEEP2 DEIMOS Pipeline
# 61           Spec2d                                    DEIMOS pipeline
# 62           Spec2d                                             Spec2d
# 63           Spec2d  The analysis pipeline used to reduce the DEIMO...
# 64           Spec2d                                    arXiv:1203.3192
# 65           Spec2d             astro.berkeley.edu/~cooper/deep/spec2d
# 66           Spec2d            astron.berkeley.edu/~cooper/deep/spec2d
# 67           Spec2d                           deep.berkeley.edu/spec2d
# 68           Spec2d                             deep.ps.uci.edu/spec2d
# 69           Spec2d                                          idlspec2d
# 70           Spec2d                    spectro.princeton.edu/idlspec2d
# 71        Stringray                                           HENDRICS
# 72        Stringray                                           Stingray
# 73           TARDIS                                             TARDIS
# 74           TARDIS                                             Tardis
# 75           TARDIS                                          tardis-sn
# 76         WCSTools                                             LibWCS
# 77         WCSTools                                          WCS Tools
# 78         WCSTools                                             WCSLIB
# 79         WCSTools                                           WCSTools
# 80         WCSTools                                            gethead
# 81         WCSTools                      harvard.edu/software/wcstools
# 82         WCSTools                                              imwcs
# 83         WCSTools                                            sethead
# 84         WCSTools                                             sky2xy
# 85         WCSTools              tdc-www.harvard.edu/software/wcstools
# 86         WCSTools                       tdc-www.harvard.edu/wcstools
# 87         WCSTools                                             wcslib
# 88         WCSTools                                             xy2sky
#
#     Identifier  cite_count
# 0            0           3
# 1            0           1
# 2            1           1
# 3            0         306
# 4            0         223
# 5            0         160
# 6            0           4
# 7            0         167
# 8            0           5
# 9            0         167
# 10           0           5
# 11           0         160
# 12           0           4
# 13           1           3
# 14           1           2
# 15           1           2
# 16           0           4
# 17           0          24
# 18           0           6
# 19           0           1
# 20           0           1
# 21           0           2
# 22           0           1
# 23           0           6
# 24           0           1
# 25           0           2
# 26           1           1
# 27           1           1
# 28           0         210
# 29           0           3
# ..         ...         ...
# 59           0           5
# 60           0           7
# 61           0          10
# 62           0          98
# 63           0           2
# 64           1          12
# 65           0           8
# 66           0           2
# 67           0           1
# 68           0           1
# 69           0          55
# 70           0           5
# 71           0           2
# 72           0         183
# 73           0          30
# 74           0          33
# 75           0           1
# 76           0           1
# 77           0           6
# 78           0          13
# 79           0         140
# 80           0          12
# 81           0           8
# 82           0          26
# 83           0           3
# 84           0           5
# 85           0           7
# 86           0           7
# 87           0          11
# 88           0           9
#
# [89 rows x 4 columns]

# %%
# proportion of identifiers among software aliases in citations 
API_identifier_prop = API_results.loc[API_results['Identifier'] == 1]
API_identifier_prop = API_identifier_prop.groupby('Software_Package')['Bibcode'].nunique()/API_results.groupby('Software_Package')['Bibcode'].nunique()
API_identifier_prop
# Out:
# Software_Package
# Astroblend           NaN
# Astropy         0.038902
# RADMC-3D        0.022277
# SAOImage DS9    0.005556
# Spec2d          0.054878
# Stringray            NaN
# TARDIS               NaN
# WCSTools        0.002994
# Name: Bibcode, dtype: float64

# %%
# total mentions of software aliases over time
API_over_time = pd.DataFrame({'year_count' : API_results.groupby(["Software_Package", "Pub_Year"])['Bibcode'].nunique()}).reset_index()
# write results
API_over_time.to_csv("API_over_time_061019.csv")
# show results over time
API_over_time
# Out:
#     Software_Package  Pub_Year  year_count
# 0         Astroblend      2016           2
# 1         Astroblend      2017           3
# 2            Astropy      1997           1
# 3            Astropy      2000           2
# 4            Astropy      2007           1
# 5            Astropy      2013           9
# 6            Astropy      2014          29
# 7            Astropy      2015          57
# 8            Astropy      2016         113
# 9            Astropy      2017         158
# 10           Astropy      2018          67
# 11          RADMC-3D      2004           5
# 12          RADMC-3D      2005           5
# 13          RADMC-3D      2006           6
# 14          RADMC-3D      2007          13
# 15          RADMC-3D      2008           9
# 16          RADMC-3D      2009          16
# 17          RADMC-3D      2010          19
# 18          RADMC-3D      2011          20
# 19          RADMC-3D      2012          29
# 20          RADMC-3D      2013          32
# 21          RADMC-3D      2014          38
# 22          RADMC-3D      2015          48
# 23          RADMC-3D      2016          71
# 24          RADMC-3D      2017          66
# 25          RADMC-3D      2018          27
# 26      SAOImage DS9      1997          25
# 27      SAOImage DS9      1998          16
# 28      SAOImage DS9      1999          10
# 29      SAOImage DS9      2000          18
# ..               ...       ...         ...
# 97            TARDIS      2011           1
# 98            TARDIS      2012           4
# 99            TARDIS      2013           7
# 100           TARDIS      2014          17
# 101           TARDIS      2015          16
# 102           TARDIS      2016          25
# 103           TARDIS      2017          28
# 104           TARDIS      2018           5
# 105         WCSTools      1997           4
# 106         WCSTools      1998           1
# 107         WCSTools      1999           5
# 108         WCSTools      2000           2
# 109         WCSTools      2001           9
# 110         WCSTools      2002          13
# 111         WCSTools      2003          10
# 112         WCSTools      2004          14
# 113         WCSTools      2005          11
# 114         WCSTools      2006          13
# 115         WCSTools      2007          21
# 116         WCSTools      2008          17
# 117         WCSTools      2009          21
# 118         WCSTools      2010          32
# 119         WCSTools      2011          29
# 120         WCSTools      2012          29
# 121         WCSTools      2013          23
# 122         WCSTools      2014          16
# 123         WCSTools      2015          20
# 124         WCSTools      2016          20
# 125         WCSTools      2017          20
# 126         WCSTools      2018           4
#
# [127 rows x 3 columns]
